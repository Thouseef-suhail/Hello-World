# %% [markdown]
# **PROBLEM STATEMENT: Predicting the  Degree of Regulatory Compliance (DRC) of the Insurers  through  evaluation of complaints resolution system  & Pattern Extraction****************************************************************************************

# %%
##STARTING THE CODE PROCESS

# %%
##IMPORTING THE LIBRARIES*************************************************************

# %%
# Modules to ignore warnings
import warnings               
warnings.filterwarnings('ignore')

import tensorflow as tf
tf.logging.set_verbosity(tf.logging.ERROR)

import os   
import shutil


import numpy as np    # For array operations
import pandas as pd   # For DataFrames
from PIL import Image
import matplotlib.image as mpimg
import matplotlib.pyplot as plt    # For plotting%matplotlib inline
from subprocess import call
import seaborn as sns
from datetime import date


import scipy.stats as sps



from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import confusion_matrix,mean_squared_error,accuracy_score
from sklearn.model_selection import train_test_split
from collections import Counter

import datetime as dt
from datetime import datetime
import time
from datetime import date
import calendar

from collections import Counter
from scipy import stats
from itertools import groupby
from operator import itemgetter

# %%
##Reading the data*******************************************************************

# %%
Train_data = pd.read_csv('Train-1564659747836.csv', index_col=0)

# %%
Train_Complaints=pd.read_csv('Train_Complaints-1564659763354.csv', index_col=0)

# %%
Test_data=pd.read_csv('Test-1565162240834.csv', index_col=0)

# %%
Test_Complaints=pd.read_csv('Test_Complaints-1565162197608.csv', index_col=0)

# %%
print('shape of Train_data:{}\n'.format((Train_data.shape)))
print('shape of Train_Complaints:{}\n'.format((Train_Complaints.shape)))
# Out:
# shape of Train_data:(539, 1)
#
# shape of Train_Complaints:(15565, 14)

# %%
print('shape of Test_data:{}\n'.format((Test_data.shape)))
print('shape of Test_Complaints:{}\n'.format((Test_Complaints.shape)))
# Out:
# shape of Test_data:(60, 0)
#
# shape of Test_Complaints:(1927, 14)

# %%
##check if train data was read properly
print("Head of Train_data:\n",Train_data.head(3))
print("Head of Test_Complaints:\n",Train_Complaints.head(3))
# Out:
# Head of Train_data:
#                DRC
# InsurerID
# Insurer5266  poor
# Insurer5330  poor
# Insurer5405  poor
# Head of Test_Complaints:
#                                         FileNo DateOfRegistration  \
# Company
# Middlesex Mutual Assurance Company     101588         2010-03-28
# Liberty Mutual Fire Insurance Company  101805         2010-04-11
# QBE Insurance Corporation              103398         2010-07-22
#
#                                       DateOfResolution           Coverage  \
# Company
# Middlesex Mutual Assurance Company          2010-04-13         Homeowners
# Liberty Mutual Fire Insurance Company       2016-11-01         Homeowners
# QBE Insurance Corporation                   2014-06-22  Condo Association
#
#                                       SubCoverage                  Reason  \
# Company
# Middlesex Mutual Assurance Company            NaN  Unfair Claims Practice
# Liberty Mutual Fire Insurance Company         NaN  Unfair Claims Practice
# QBE Insurance Corporation                     NaN  Unfair Claims Practice
#
#                                              SubReason  \
# Company
# Middlesex Mutual Assurance Company        Claim Delays
# Liberty Mutual Fire Insurance Company  Claim Procedure
# QBE Insurance Corporation              Denial of Claim
#
#                                               EnforcementAction   Conclusion  \
# Company
# Middlesex Mutual Assurance Company      Company Position Upheld  Unjustified
# Liberty Mutual Fire Insurance Company  Satisfactory Explanation  Unjustified
# QBE Insurance Corporation               Company Position Upheld  Unjustified
#
#                                        RecoveredFromInsurer ResolutionStatus  \
# Company
# Middlesex Mutual Assurance Company                      0.0           Closed
# Liberty Mutual Fire Insurance Company                   0.0           Closed
# QBE Insurance Corporation                               0.0           Closed
#
#                                        ComplaintID    InsurerID        State
# Company
# Middlesex Mutual Assurance Company          345501  Insurer5626  Connecticut
# Liberty Mutual Fire Insurance Company       345502  Insurer5589  Connecticut
# QBE Insurance Corporation                   345503  Insurer5750  Connecticut

# %%
##check if train data was read properly
print("Head of Test_data:\n",Test_data.head(3))
print("Head of Test_Complaints:\n",Test_Complaints.head(3))
# Out:
# Head of Test_data:
#  Empty DataFrame
# Columns: []
# Index: [Insurer5355, Insurer5491, Insurer5687]
# Head of Test_Complaints:
#                                FileNo DateOfRegistration DateOfResolution  \
# Company
# Aetna Life Insurance Company  404512         2013-09-09       2014-02-18
# Aetna Life Insurance Company  404512         2013-09-09       2014-02-18
# Aetna Life Insurance Company  404755         2013-09-23       2014-01-02
#
#                                              Coverage         SubCoverage  \
# Company
# Aetna Life Insurance Company        Individual Health  Health Care Reform
# Aetna Life Insurance Company                      NaN                 NaN
# Aetna Life Insurance Company  Group Disability Income     Long Term Group
#
#                                               Reason  \
# Company
# Aetna Life Insurance Company         Marketing/Sales
# Aetna Life Insurance Company         Marketing/Sales
# Aetna Life Insurance Company  Unfair Claims Practice
#
#                                               SubReason  \
# Company
# Aetna Life Insurance Company  Discontinuation & Replmnt
# Aetna Life Insurance Company  Discontinuation & Replmnt
# Aetna Life Insurance Company            Denial of Claim
#
#                                      EnforcementAction             Conclusion  \
# Company
# Aetna Life Insurance Company  Satisfactory Explanation              Justified
# Aetna Life Insurance Company  Satisfactory Explanation              Justified
# Aetna Life Insurance Company  Satisfactory Explanation  Furnished Information
#
#                               RecoveredFromInsurer ResolutionStatus  \
# Company
# Aetna Life Insurance Company                   0.0           Closed
# Aetna Life Insurance Company                   0.0           Closed
# Aetna Life Insurance Company                   0.0           Closed
#
#                               ComplaintID    InsurerID        State
# Company
# Aetna Life Insurance Company       345544  Insurer5268  Connecticut
# Aetna Life Insurance Company       345545  Insurer5268  Connecticut
# Aetna Life Insurance Company       345556  Insurer5268  Connecticut

# %%
Train_data.describe()
# Out:
#                 DRC
# count           539
# unique            3
# top     outstanding
# freq            276

# %%
Train_Complaints.describe()
# Out:
#               FileNo  RecoveredFromInsurer    ComplaintID
# count   15565.000000          15565.000000   15565.000000
# mean   666343.643302           1253.019656  354333.728943
# std    129338.222318          14983.840980    5077.961449
# min    101588.000000              0.000000  345501.000000
# 25%    600208.000000              0.000000  349968.000000
# 50%    700676.000000              0.000000  354330.000000
# 75%    801379.000000              0.000000  358740.000000
# max    902189.000000         843825.850000  363104.000000

# %%
Test_Complaints.describe()
# Out:
#               FileNo  RecoveredFromInsurer    ComplaintID
# count    1927.000000           1927.000000    1927.000000
# mean   659091.508044           1537.660701  354115.535029
# std    129082.226160          11359.210936    5089.834616
# min    404512.000000              0.000000  345544.000000
# 25%    505331.500000              0.000000  349487.000000
# 50%    700334.000000              0.000000  354093.000000
# 75%    800965.000000              0.000000  358472.500000
# max    902097.000000         250000.000000  363100.000000

# %%
Train_data.head()
# Out:
#               DRC
# InsurerID
# Insurer5266  poor
# Insurer5330  poor
# Insurer5405  poor
# Insurer5866  poor
# Insurer5283  poor

# %%
Test_data.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: [Insurer5355, Insurer5491, Insurer5687, Insurer5500, Insurer5268]

# %%
##MERGING THE DATASETS INTO DATA_TRAIN AND TEST_DATA*************************************

# %%
data_train=pd.merge(Train_data, Train_Complaints, on='InsurerID', how='inner')

# %%
data_test=pd.merge(Test_data, Test_Complaints, on='InsurerID', how='inner')

# %%
print('shape of data_test:{}\n'.format((data_train.shape)))
# Out:
# shape of data_test:(15565, 15)

# %%
print('shape of data_test:{}\n'.format((data_test.shape)))
# Out:
# shape of data_test:(1927, 14)

# %%
data_train.head()
# Out:
#      InsurerID   DRC  FileNo DateOfRegistration DateOfResolution  \
# 0  Insurer5266  poor  403737         2013-07-25       2014-05-20
# 1  Insurer5266  poor  403737         2013-07-25       2014-05-20
# 2  Insurer5266  poor  405258         2013-10-24       2014-02-05
# 3  Insurer5266  poor  405258         2013-10-24       2014-02-05
# 4  Insurer5266  poor  405979         2013-12-04       2014-02-19
#
#                    Coverage     SubCoverage                  Reason  \
# 0  Exchange-Individual Hlth  No SubCov - AH         Marketing/Sales
# 1                       NaN             NaN         Marketing/Sales
# 2                       NaN             NaN  Unfair Claims Practice
# 3         Individual Health  No SubCov - AH  Unfair Claims Practice
# 4              Group Health             MRI       Statute Violation
#
#                    SubReason         EnforcementAction Conclusion  \
# 0  Discontinuation & Replmnt  Claim Paid With Interest  Justified
# 1  Discontinuation & Replmnt  Claim Paid With Interest  Justified
# 2            Denial of Claim  Claim Paid With Interest  Justified
# 3            Denial of Claim  Claim Paid With Interest  Justified
# 4               No Subreason         Corrective Action  Justified
#
#    RecoveredFromInsurer ResolutionStatus  ComplaintID        State
# 0              38220.25           Closed       345537  Connecticut
# 1              38220.25           Closed       345539  Connecticut
# 2                 13.00           Closed       345585  Connecticut
# 3                 13.00           Closed       345586  Connecticut
# 4             136808.00           Closed       345657  Connecticut

# %%
data_test.head()
# Out:
#      InsurerID  FileNo DateOfRegistration DateOfResolution  \
# 0  Insurer5355  406310         2013-12-30       2014-02-05
# 1  Insurer5355  406310         2013-12-30       2014-02-05
# 2  Insurer5355  500646         2014-02-13       2014-03-02
# 3  Insurer5355  500646         2014-02-13       2014-03-02
# 4  Insurer5355  500853         2014-02-23       2014-03-17
#
#                     Coverage     SubCoverage                  Reason  \
# 0  Individual Long Term Care     Partnership  Unfair Claims Practice
# 1                        NaN             NaN  Unfair Claims Practice
# 2                        NaN             NaN            Underwriting
# 3  Individual Long Term Care  No SubCov - AH            Underwriting
# 4            Individual Life      Whole Life            Underwriting
#
#            SubReason         EnforcementAction             Conclusion  \
# 0    Claim Procedure  Claim Paid With Interest              Justified
# 1    Claim Procedure  Claim Paid With Interest              Justified
# 2       Cancellation     Furnished Information  Furnished Information
# 3       Cancellation     Furnished Information  Furnished Information
# 4  Refusal to Insure   Company Position Upheld            Unjustified
#
#    RecoveredFromInsurer ResolutionStatus  ComplaintID        State
# 0              27325.73           Closed       345815  Connecticut
# 1              27325.73           Closed       345822  Connecticut
# 2                  0.00           Closed       346286  Connecticut
# 3                  0.00           Closed       346289  Connecticut
# 4                  0.00           Closed       346390  Connecticut

# %%
data_train.dtypes
# Out:
# InsurerID                object
# DRC                      object
# FileNo                    int64
# DateOfRegistration       object
# DateOfResolution         object
# Coverage                 object
# SubCoverage              object
# Reason                   object
# SubReason                object
# EnforcementAction        object
# Conclusion               object
# RecoveredFromInsurer    float64
# ResolutionStatus         object
# ComplaintID               int64
# State                    object
# dtype: object

# %%
data_test.dtypes
# Out:
# InsurerID                object
# FileNo                    int64
# DateOfRegistration       object
# DateOfResolution         object
# Coverage                 object
# SubCoverage              object
# Reason                   object
# SubReason                object
# EnforcementAction        object
# Conclusion               object
# RecoveredFromInsurer    float64
# ResolutionStatus         object
# ComplaintID               int64
# State                    object
# dtype: object

# %%
##PREPROCESSING***********************************************************************

# %% [markdown]
# ##Replacing empty space with nan values

# %%
data_train= data_train.replace(r'^\s+$', np.nan, regex=True)

# %%
data_test= data_test.replace(r'^\s+$', np.nan, regex=True)

# %%
#Replacing empty space with nan values***************************************

# %%
data_train[data_train.duplicated(['InsurerID'])==True].sort_values('InsurerID')
# Out:
#          InsurerID          DRC  FileNo DateOfRegistration DateOfResolution  \
# 11507  Insurer5252  outstanding  505530         2014-12-08       2015-01-26
# 11517  Insurer5252  outstanding  705302         2016-11-22       2017-01-03
# 11516  Insurer5252  outstanding  705320         2016-11-22       2016-12-07
# 11515  Insurer5252  outstanding  701892         2016-04-21       2016-05-02
# 11514  Insurer5252  outstanding  604954         2015-10-28       2015-11-03
# 11513  Insurer5252  outstanding  603653         2015-08-08       2015-09-07
# 11512  Insurer5252  outstanding  603653         2015-08-08       2015-09-07
# 11511  Insurer5252  outstanding  600356         2015-01-26       2015-02-10
# 11510  Insurer5252  outstanding  600356         2015-01-26       2015-02-10
# 11509  Insurer5252  outstanding  600004         2015-01-04       2015-01-13
# 11508  Insurer5252  outstanding  505873         2014-12-31       2015-01-06
# 11518  Insurer5252  outstanding  705302         2016-11-22       2017-01-03
# 11506  Insurer5252  outstanding  505396         2014-11-30       2014-12-10
# 11504  Insurer5252  outstanding  504791         2014-10-19       2014-11-04
# 11503  Insurer5252  outstanding  504791         2014-10-19       2014-11-04
# 11502  Insurer5252  outstanding  504530         2014-10-01       2014-11-24
# 11501  Insurer5252  outstanding  504062         2014-09-01       2014-09-14
# 11500  Insurer5252  outstanding  503458         2014-07-28       2014-08-06
# 11499  Insurer5252  outstanding  503244         2014-07-14       2014-08-10
# 11498  Insurer5252  outstanding  503133         2014-07-08       2014-08-06
# 11497  Insurer5252  outstanding  501537         2014-04-02       2014-04-07
# 11496  Insurer5252  outstanding  500088         2014-01-09       2014-01-30
# 11495  Insurer5252  outstanding  405995         2013-12-08       2014-01-21
# 11505  Insurer5252  outstanding  505396         2014-11-30       2014-12-10
# 11502                      Auto         NaN            Underwriting
# 11501                      Auto         NaN      Premium and Rating
# 11500            Auto Liability         NaN  Unfair Claims Practice
# 11499            Auto Liability         NaN  Unfair Claims Practice
# 11498      Auto Physical Damage         NaN  Unfair Claims Practice
# 11497                Homeowners         NaN            Underwriting
# 11496                      Auto         NaN            Underwriting
# 11495                       NaN         NaN            Underwriting
# 11505                      Auto         NaN      Premium and Rating
# 14372            Auto Liability         NaN  Unfair Claims Practice
# 14375           Individual Life   Term Life            Underwriting
# 14377                Homeowners         NaN            Underwriting
# 7276       Auto Physical Damage         NaN  Unfair Claims Practice
# 7277                        NaN         NaN  Unfair Claims Practice
# 7281                 Homeowners         NaN  Unfair Claims Practice
# ...                         ...         ...                     ...
# 11489    Other [Enter Coverage]         NaN      Premium and Rating
# 11488    Other [Enter Coverage]         NaN      Premium and Rating
# 11492    Other [Enter Coverage]         NaN  Unfair Claims Practice
# 8552             Auto Liability         NaN  Unfair Claims Practice
# 8560                        NaN         NaN  Unfair Claims Practice
# 8561             Auto Liability         NaN  Unfair Claims Practice
# 8562          General Liability         NaN  Unfair Claims Practice
# 8563                        NaN         NaN  Unfair Claims Practice
# 8564   Extended Warranty(Other)         NaN  Unfair Claims Practice
# 8541      Worker's Compensation         NaN            Underwriting
# 8542      Worker's Compensation         NaN  Unfair Claims Practice
# 8543             Auto Liability         NaN  Unfair Claims Practice
# 8544                        NaN         NaN  Unfair Claims Practice
# 8545            Commercial Auto         NaN         Marketing/Sales
# 8553       Auto Physical Damage         NaN  Unfair Claims Practice
# 8546          General Liability         NaN  Unfair Claims Practice
# 8548    Auto Uninsured Motorist         NaN  Unfair Claims Practice
# 8549             Auto Liability         NaN  Unfair Claims Practice
# 8550            Commercial Auto         NaN         Marketing/Sales
# 8551                        NaN         NaN  Unfair Claims Practice
# 8565            Commercial Auto         NaN      Premium and Rating
# 8566                        NaN         NaN      Premium and Rating
# 8558             Auto Liability         NaN  Unfair Claims Practice
# 8557                        NaN         NaN  Unfair Claims Practice
# 8556     Commercial Multi-Peril         NaN  Unfair Claims Practice
# 8555          General Liability         NaN  Unfair Claims Practice
# 8554      Worker's Compensation         NaN      Premium and Rating
# 8547             Auto Liability         NaN  Unfair Claims Practice
# 8559             Auto Liability         NaN  Unfair Claims Practice
# 15103            Auto Liability         NaN  Unfair Claims Practice
#
#                        SubReason         EnforcementAction  \
# 11507               Cancellation       Cancellation Upheld
# 11517            Denial of Claim        Contract Provision
# 11516          Excessive Charges   Company Position Upheld
# 11515                Non-Renewal        Non-Renewal Upheld
# 11514                Non-Renewal        Non-Renewal Upheld
# 11513       Unsatisfactory Offer        Refer To Appraisal
# 11512               Claim Delays        Refer To Appraisal
# 11511   Other [Enter Sub-Reason]  Satisfactory Explanation
# 11510   Other [Enter Sub-Reason]  Satisfactory Explanation
# 11509            Denial of Claim   Company Position Upheld
# 11508                Subrogation  Satisfactory Explanation
# 11518            Denial of Claim        Contract Provision
# 11506                Non-Renewal        Non-Renewal Upheld
# 11504            Claim Procedure   Company Position Upheld
# 14375            Unjustified                  0.00           Closed
# 14377  Furnished Information                  0.00           Closed
# 7276             Unjustified                  0.00           Closed
# 7277             Unjustified                  0.00           Closed
# 7281             Unjustified                  0.00           Closed
# ...                      ...                   ...              ...
# 11489            Unjustified                  0.00           Closed
# 11488            Unjustified                  0.00           Closed
# 11492    No Action Necessary                  0.00           Closed
# 8552             Unjustified                  0.00           Closed
# 8560             Unjustified                  0.00           Closed
# 8561            Questionable               3117.88           Closed
# 8562             Unjustified                  0.00           Closed
# 8563             Unjustified                  0.00           Closed
# 8564             Unjustified                  0.00        Re-Opened
# 8541             Unjustified                  0.00           Closed
# 8542             Unjustified                  0.00           Closed
# 8543             Unjustified                  0.00           Closed
# 8544             Unjustified                  0.00           Closed
# 8545             Unjustified                  0.00           Closed
# 8553             Unjustified               7150.91           Closed
# 8546             Unjustified               8690.63           Closed
# 8548             Unjustified                  0.00           Closed
# 8549             Unjustified                  0.00           Closed
# 8550             Unjustified                  0.00           Closed
# 8551             Unjustified                  0.00           Closed
# 8565             Unjustified                  0.00           Closed
# 8566             Unjustified                  0.00           Closed
# 8558             Unjustified                  0.00           Closed
# 8557             Unjustified                  0.00           Closed
# 8556    Voluntary Reconsider               1700.00           Closed
# 8555             Unjustified                  0.00           Closed
# 8554             Unjustified                  0.00           Closed
# 8547             Unjustified                  0.00           Closed
# 8559             Unjustified                  0.00           Closed
# 15103           Questionable                688.46           Closed
#
#        ComplaintID        State
# 11507       349603  Connecticut
# 11517       357473  Connecticut
# 11516       357462  Connecticut
# 11515       355117  Connecticut
# 11514       353186  Connecticut
# 11513       352292  Connecticut
# 11512       352291  Connecticut
# 11511       350069  Connecticut
# 11510       350068  Connecticut
# 11509       349838  Connecticut
# 11508       349830  Connecticut
# 11518       357474  Connecticut
# 11506       349532  Connecticut
# 11504       349144  Connecticut
# 11503       349129  Connecticut
# 11502       348943  Connecticut
# 11501       348639  Connecticut
# 11500       348244  Connecticut
# 11499       348066  Connecticut
# 11498       347993  Connecticut
# 11497       346871  Connecticut
# 11496       345906  Connecticut
# 11495       345675  Connecticut
# 11505       349531  Connecticut
# 14372       354151  Connecticut
# 14375       356953  Connecticut
# 14377       347696  Connecticut
# 7276        348015  Connecticut
# 7277        348033  Connecticut
# 7281        348970  Connecticut
# ...            ...          ...
# 11489       358689  Connecticut
# 11488       357364  Connecticut
# 11492       363038  Connecticut
# 8552        353631  Connecticut
# 8560        358865  Connecticut
# 8561        360874  Connecticut
# 8562        362032  Connecticut
# 8563        362033  Connecticut
# 8564        362082  Connecticut
# 8541        346975  Connecticut
# 8542        348630  Connecticut
# 8543        348631  Connecticut
# 8544        348635  Connecticut
# 8545        350835  Connecticut
# 8553        355520  Connecticut
# 8546        352159  Connecticut
# 8548        352629  Connecticut
# 8549        353072  Connecticut
# 8550        353379  Connecticut
# 8551        353629  Connecticut
# 8565        362826  Connecticut
# 8566        362828  Connecticut
# 8558        358860  Connecticut
# 8557        358858  Connecticut
# 8556        357678  Connecticut
# 8555        357237  Connecticut
# 8554        357022  Connecticut
# 1912  Insurer5865  703069         2016-07-03       2016-07-27
# 1693  Insurer5867  602740         2015-06-14       2015-07-13
# 1694  Insurer5867  805810         2017-12-17       2017-12-27
# 1690  Insurer5867  505439         2014-12-01       2014-12-09
# 1691  Insurer5867  601251         2015-03-17       2015-04-07
# 1692  Insurer5867  601251         2015-03-17       2015-04-07
# 1920  Insurer5895  504124         2014-09-04       2014-10-15
# 1921  Insurer5895  805314         2017-11-09       2017-11-30
# 1922  Insurer5895  805314         2017-11-09       2017-11-30
# 1923  Insurer5895  900535         2018-02-04       2018-03-18
# 1924  Insurer5895  900535         2018-02-04       2018-03-18
#
#                       Coverage               SubCoverage  \
# 938               Group Health   Behavl Hlth/Subst Abuse
# 758                 Group Life                 Term Life
# 759               Group Health              Preventative
# 760    Group Disability Income          Short Term Group
# 761                        NaN                       NaN
# 762          Individual Health                     Other
# 763               Group Health              Preventative
# 764          Individual Health                In-Patient
# 765                        NaN                       NaN
# 766               Group Health              Prescription
# 767               Group Health      Occupational Therapy
# 768                        NaN                       NaN
# 769               Group Health               Out-Patient
# 757                        NaN                       NaN
# 770         Short Term Medical                 Maternity
# 772               Group Health                 Ambulance
# 773                        NaN                       NaN
# 774                 Group Life                 Term Life
# 775                        NaN                       NaN
# 776               Group Health            No SubCov - AH
# 777                        NaN                       NaN
# 778          Individual Health            No SubCov - AH
# 779               Group Health                 Ambulance
# 780                     Dental                    Dental
# 781                        NaN                       NaN
# 782               Group Health            No SubCov - AH
# 783   Exchange-Individual Hlth            No SubCov - AH
# 771                 Group Life                 Term Life
# 784                 Group Life                 Term Life
# 756    Group Disability Income           Long Term Group
# ...                        ...                       ...
# 1817         General Liability                       NaN
# 1819    Commercial Multi-Peril                       NaN
# 1815         Tenant Homeowners                       NaN
# 1806                Homeowners                       NaN
# 1807                Homeowners                       NaN
# 1809                Homeowners                       NaN
# 1810                Homeowners                       NaN
# 1808          Travel Insurance                       NaN
# 1812                Homeowners                       NaN
# 1813                       NaN                       NaN
# 1814    Commercial Multi-Peril                       NaN
# 1811                Homeowners                       NaN
# 1914   Group/Association Trust            No SubCov - AH
# 1911                       NaN                       NaN
# 1913   Group/Association Trust  Skill Nurs/Home Hth Care
# 1915                     A & H            No SubCov - AH
# 1908   Group/Association Trust            No SubCov - AH
# 1909   Group/Association Trust                 Term Life
# 1910           Individual Life                Whole Life
# 1912                       NaN                       NaN
# 1693         Individual Health              Prescription
# 1694              Group Health            No SubCov - AH
# 1690         Individual Health            No SubCov - AH
# 1691                       NaN                       NaN
# 1692  Exchange-Individual Hlth                In-Patient
# 1920        Medicare Advantage            No SubCov - AH
# 1921        Medicare Advantage            No SubCov - AH
# 1922                       NaN                       NaN
# 1923        Medicare Part D Rx            No SubCov - AH
# 1924                       NaN                       NaN
#
#                       Reason                  SubReason  \
# 938   Unfair Claims Practice    Provider Contract Issue
# 758   Unfair Claims Practice            Denial of Claim
# 759   Unfair Claims Practice  Unsatisfactory Settlement
# 760   Unfair Claims Practice               Claim Delays
# 761       Utilization Review          Medical Necessity
# 762       Utilization Review          Medical Necessity
# 776            Closed       350565  Connecticut
# 777            Closed       350590  Connecticut
# 778            Closed       350593  Connecticut
# 779            Closed       350682  Connecticut
# 780            Closed       350683  Connecticut
# 781            Closed       350706  Connecticut
# 782            Closed       350734  Connecticut
# 783            Closed       350754  Connecticut
# 771            Closed       350393  Connecticut
# 784            Closed       350761  Connecticut
# 756            Closed       349578  Connecticut
# ...               ...          ...          ...
# 1817           Closed       357703  Connecticut
# 1819           Closed       358275  Connecticut
# 1815           Closed       357063  Connecticut
# 1806           Closed       353999  Connecticut
# 1807           Closed       354217  Connecticut
# 1809           Closed       355514  Connecticut
# 1810           Closed       355515  Connecticut
# 1808           Closed       355505  Connecticut
# 1812           Closed       356417  Connecticut
# 1813           Closed       356418  Connecticut
# 1814           Closed       356718  Connecticut
# 1811           Closed       355906  Connecticut
# 1914           Closed       356161  Connecticut
# 1911           Closed       355733  Connecticut
# 1913           Closed       355947  Connecticut
# 1915           Closed       356398  Connecticut
# 1908           Closed       350898  Connecticut
# 1909           Closed       352894  Connecticut
# 1910           Closed       355732  Connecticut
# 1912           Closed       355944  Connecticut
# 1693           Closed       351689  Connecticut
# 1694           Closed       361770  Connecticut
# 1690           Closed       349570  Connecticut
# 1691           Closed       350727  Connecticut
# 1692           Closed       350735  Connecticut
# 1920           Closed       348702  Connecticut
# 1921           Closed       361452  Connecticut
# 1922           Closed       361453  Connecticut
# 1923           Closed       362255  Connecticut
# 1924           Closed       362256  Connecticut
#
# [1867 rows x 14 columns]

# %%
data_train.shape
# Out:
# (15565, 15)

# %%
data_test.shape
# Out:
# (1927, 14)

# %%
##finding the repeated InsurerID in data set 
data_train.InsurerID.duplicated().sum()
# Out:
# 15026

# %%
##finding the repeated InsurerID in data set 
data_test.InsurerID.duplicated().sum()
# Out:
# 1867

# %%
##checking individual InsurerID occuring in data set
pd.value_counts(data_train['InsurerID'].values)
# Out:
# Insurer5330    1954
# Insurer5406     622
# Insurer5281     564
# Insurer5490     401
# Insurer5404     394
# Insurer5866     386
# Insurer5405     372
# Insurer5733     300
# Insurer5283     292
# Insurer5732     287
# Insurer5700     281
# Insurer5797     244
# Insurer5598     240
# Insurer5799     207
# Insurer5546     200
# Insurer5387     190
# Insurer5763     190
# Insurer5790     182
# Insurer5826     182
# Insurer5589     171
# Insurer5291     171
# Insurer5846     165
# Insurer5326     160
# Insurer5836     138
# Insurer5620     133
# Insurer5656     119
# Insurer5875     117
# Insurer5874     117
# Insurer5482     115
# Insurer5619     113
#                ...
# Insurer5294       1
# Insurer5847       1
# Insurer5778       1
# Insurer5631       1
# Insurer5492       1
# Insurer5352       1
# Insurer5434       1
# Insurer5457       1
# Insurer5278       1
# Insurer5705       1
# Insurer5737       1
# Insurer5456       1
# Insurer5304       1
# Insurer5475       1
# Insurer5466       1
# Insurer5363       1
# Insurer5302       1
# Insurer5628       1
# Insurer5313       1
# Insurer5711       1
# Insurer5739       1
# Insurer5829       1
# Insurer5458       1
# Insurer5479       1
# Insurer5810       1
# Insurer5555       1
# Insurer5531       1
# Insurer5746       1
# Insurer5449       1
# Insurer5376       1
# Length: 539, dtype: int64

# %%
##checking individual InsurerID occuring in data set
pd.value_counts(data_test['InsurerID'].values)
# Out:
# Insurer5268    388
# Insurer5491    376
# Insurer5365    127
# Insurer5586    123
# Insurer5500    110
# Insurer5355     94
# Insurer5549     92
# Insurer5850     54
# Insurer5539     48
# Insurer5488     45
# Insurer5289     40
# Insurer5662     37
# Insurer5543     33
# Insurer5307     33
# Insurer5704     30
# Insurer5687     25
# Insurer5516     22
# Insurer5610     22
# Insurer5410     20
# Insurer5552     17
# Insurer5644     14
# Insurer5374     14
# Insurer5848     11
# Insurer5754     10
# Insurer5351     10
# Insurer5673     10
# Insurer5865      9
# Insurer5443      8
# Insurer5816      8
# Insurer5287      7
# Insurer5453      7
# Insurer5895      6
# Insurer5867      6
# Insurer5364      6
# Insurer5401      5
# Insurer5761      5
# Insurer5558      5
# Insurer5373      5
# Insurer5269      4
# Insurer5792      4
# Insurer5305      4
# Insurer5667      3
# Insurer5501      3
# Insurer5532      3
# Insurer5771      3
# Insurer5511      3
# Insurer5470      2
# Insurer5643      2
# Insurer5382      2
# Insurer5789      2
# Insurer5312      1
# Insurer5581      1
# Insurer5680      1
# Insurer5331      1
# Insurer5730      1
# Insurer5303      1
# Insurer5712      1
# Insurer5455      1
# Insurer5442      1
# Insurer5577      1
# dtype: int64

# %%
##sorting the dates in descending order to get the top get insurerID

# %%
data_train.sort_values(by=['DateOfRegistration'], inplace=True, ascending=False)

# %%
data_train
# Out:
#          InsurerID          DRC  FileNo DateOfRegistration DateOfResolution  \
# 14641  Insurer5324  outstanding  902189         2018-05-14       2018-05-15
# 3100   Insurer5283         poor  902189         2018-05-14       2018-05-15
# 13619  Insurer5826         poor  902167         2018-05-13       2018-05-15
# 15398  Insurer5743  outstanding  902137         2018-05-10       2018-05-15
# 15326  Insurer5595  outstanding  902080         2018-05-08       2018-05-13
# 10640  Insurer5827  outstanding  902074         2018-05-08       2018-05-09
# 11388  Insurer5620      average  902064         2018-05-08       2018-05-09
# 13618  Insurer5826         poor  902032         2018-05-06       2018-05-06
# 4911   Insurer5762         poor  902035         2018-05-06       2018-05-15
# 3916   Insurer5490      average  902001         2018-05-03              NaN
# 11486  Insurer5621  outstanding  902011         2018-05-03       2018-05-14
# 11485  Insurer5621  outstanding  902011         2018-05-03       2018-05-14
# 2049   Insurer5330         poor  902004         2018-05-03       2018-05-10
# 2050   Insurer5330         poor  902004         2018-05-03       2018-05-10
# 4772   Insurer5700         poor  901972         2018-05-01       2018-05-10
# 13617  Insurer5826         poor  901958         2018-04-30       2018-04-30
# 13003  Insurer5756  outstanding  901965         2018-04-30       2018-05-14
# 8345   Insurer5291      average  901964         2018-04-30       2018-05-14
# 4446   Insurer5598         poor  901938         2018-04-29       2018-05-15
# 15147  Insurer5567  outstanding  901941         2018-04-29       2018-05-13
# 3099   Insurer5283         poor  901931         2018-04-29       2018-05-07
# 2048   Insurer5330         poor  901944         2018-04-29       2018-05-15
# 4445   Insurer5598         poor  901938         2018-04-29       2018-05-15
# 13615  Insurer5826         poor  901925         2018-04-26       2018-04-29
# 4446     Auto Uninsured Motorist                        NaN
# 15147           Condo Unit Owner                        NaN
# 3099                  Homeowners                        NaN
# 2048                Group Health             No SubCov - AH
# 4445                         NaN                        NaN
# 13615  Individual Long Term Care       Long Term Individual
# 13616  Individual Long Term Care       Long Term Individual
# 2047                Group Health                Colonoscopy
# 6507    Exchange-Individual Hlth             No SubCov - AH
# 11809             Auto Liability                        NaN
# 11810                        NaN                        NaN
# 12497       Auto Physical Damage                        NaN
# ...                          ...                        ...
# 5850      Commercial Multi-Peril                        NaN
# 5849                         NaN                        NaN
# 5848      Commercial Multi-Peril                        NaN
# 99      Exchange-Individual Hlth                     Autism
# 15442     Commercial Multi-Peril                        NaN
# 15443                        NaN                        NaN
# 15159      Worker's Compensation                        NaN
# 15160                        NaN                        NaN
# 5911              Auto Liability                        NaN
# 14703             Auto Liability                        NaN
# 2052             Exchange-Dental                     Dental
# 98                  Group Health               Lab Services
# 10887            Commercial Auto                        NaN
# 97      Exchange-Individual Hlth                      Other
# 11738     Commercial Multi-Peril                        NaN
# 5924                Group Health             No SubCov - AH
# 15372     Commercial Multi-Peril                        NaN
# 15373                        NaN                        NaN
# 2051                Group Health               Lab Services
# 2423           Individual Health                      Other
# 4493                         NaN                        NaN
# 4492                Group Health  Durable Medical Equipment
# 5881             Individual Life   Viatical/Life Settlement
# 3971                  Homeowners                        NaN
# 3268                     Unknown                        NaN
# 5847                     Unknown                        NaN
# 12859          Condo Association                        NaN
# 15364          Condo Association                        NaN
# 3970                  Homeowners                        NaN
# 3267                  Homeowners                        NaN
#
#                        Reason                  SubReason  \
# 14641  Unfair Claims Practice            Denial of Claim
# 3100   Unfair Claims Practice  Unsatisfactory Settlement
# 13619      Premium and Rating      Premium/Rate Increase
# 15398         Marketing/Sales       Policy Service Delay
# 15326         Marketing/Sales             Policy Service
# 10640      Premium and Rating      Premium/Rate Increase
# 11388      Premium and Rating      Premium/Rate Increase
# 13618      Premium and Rating      Premium/Rate Increase
# 4911   Unfair Claims Practice       Unsatisfactory Offer
# 3916       Premium and Rating             Premium/Notice
# 11486      Premium and Rating                 Other Fees
# 11485      Premium and Rating                 Other Fees
# 2049   Unfair Claims Practice            Denial of Claim
# 2050   Unfair Claims Practice            Denial of Claim
# 4772   Unfair Claims Practice  Unsatisfactory Settlement
# 13617      Premium and Rating      Premium/Rate Increase
# 13003      Premium and Rating      Premium/Rate Increase
# 8345   Unfair Claims Practice            Denial of Claim
# 4446   Unfair Claims Practice            Denial of Claim
# 15147  Unfair Claims Practice       Unsatisfactory Offer
# 3099   Unfair Claims Practice            Claim Procedure
# 2048   Unfair Claims Practice    Coordination of Benefit
# 4445   Unfair Claims Practice            Denial of Claim
# 13615      Premium and Rating      Premium/Rate Increase
# 13616      Premium and Rating      Premium/Rate Increase
# 2047   Unfair Claims Practice    Eligibility of Provider
# 6507          Marketing/Sales  Discontinuation & Replmnt
# 11809  Unfair Claims Practice     Comparative Negligence
# 11810  Unfair Claims Practice     Comparative Negligence
# 12497  Unfair Claims Practice  Actual Cash Value Dispute
# ...                       ...                        ...
# 15442    Company Position Upheld            Unjustified                  0.00
# 15443    Company Position Upheld            Unjustified                  0.00
# 15159    Company Position Upheld            Unjustified                  0.00
# 15160    Company Position Upheld            Unjustified                  0.00
# 5911     Company Position Upheld            Unjustified                  0.00
# 14703    Company Position Upheld            Unjustified                  0.00
# 2052          Contract Provision    No Action Necessary                  0.00
# 98     Additional Money Received              Justified                159.60
# 10887         Contract Provision            Unjustified                  0.00
# 97                 Claim Settled              Justified               1127.43
# 11738              Claim Settled            Unjustified                  0.00
# 5924       Furnished Information  Furnished Information                  0.00
# 15372         Non-Renewal Upheld            Unjustified                  0.00
# 15373         Non-Renewal Upheld            Unjustified                  0.00
# 2051     Company Position Upheld    No Action Necessary                  0.00
# 2423           Corrective Action  Furnished Information                  0.00
# 4493   Other [Enter Disposition]  Furnished Information                  0.00
# 4492   Other [Enter Disposition]  Furnished Information                  0.00
# 5881       Furnished Information  Furnished Information                  0.00
# 3971       Furnished Information  Furnished Information                  0.00
# 3268       Furnished Information  Furnished Information                  0.00
# 5847       Furnished Information  Furnished Information                  0.00
# 12859    Company Position Upheld            Unjustified                  0.00
# 15364              Claim Settled            Unjustified              18796.82
# 3970    Satisfactory Explanation            Unjustified                  0.00
# 3267     Company Position Upheld            Unjustified                  0.00
#
#       ResolutionStatus  ComplaintID        State
# 14641           Closed       363104  Connecticut
# 3100            Closed       363103  Connecticut
# 13619           Closed       363102  Connecticut
# 15398           Closed       363101  Connecticut
# 15326           Closed       363099  Connecticut
# 10640           Closed       363098  Connecticut
# 11388           Closed       363097  Connecticut
# 13618           Closed       363093  Connecticut
# 4911            Closed       363094  Connecticut
# 3916              Open       363092  Connecticut
# 11486           Closed       363091  Connecticut
# 11485           Closed       363090  Connecticut
# 2049            Closed       363088  Connecticut
# 2050            Closed       363089  Connecticut
# 4772            Closed       363087  Connecticut
# 13617           Closed       363083  Connecticut
# 13003           Closed       363084  Connecticut
# 8345            Closed       363085  Connecticut
# 4446            Closed       363082  Connecticut
# 15147           Closed       363079  Connecticut
# 3099            Closed       363078  Connecticut
# 2048            Closed       363081  Connecticut
# 4445            Closed       363080  Connecticut
# 13615           Closed       363069  Connecticut
# 13616        Re-Opened       363073  Connecticut
# 2047            Closed       363071  Connecticut
# 6507            Closed       363070  Connecticut
# 11809           Closed       363076  Connecticut
# 11810           Closed       363077  Connecticut
# 12497           Closed       363072  Connecticut
# ...                ...          ...          ...
# 5850            Closed       345531  Connecticut
# 5849            Closed       345530  Connecticut
# 5848            Closed       345529  Connecticut
# 99              Closed       345528  Connecticut
# 15442           Closed       345526  Connecticut
# 15443           Closed       345527  Connecticut
# 15159           Closed       345524  Connecticut
# 15160           Closed       345525  Connecticut
# 5911            Closed       345522  Connecticut
# 14703           Closed       345523  Connecticut
# 2052            Closed       345521  Connecticut
# 98              Closed       345520  Connecticut
# 10887           Closed       345519  Connecticut
# 97              Closed       345518  Connecticut
# 11738           Closed       345517  Connecticut
# 5924            Closed       345516  Connecticut
# 15372           Closed       345514  Connecticut
# 15373           Closed       345515  Connecticut
# 616   Insurer5268  406023         2013-12-08       2014-01-29
# 615   Insurer5268  406009         2013-12-08       2014-01-16
# 614   Insurer5268  406009         2013-12-08       2014-01-16
# 613   Insurer5268  405982         2013-12-04       2014-01-08
# 1832  Insurer5754  405963         2013-12-03       2014-02-18
# 612   Insurer5268  405936         2013-12-02       2014-01-16
# 94    Insurer5491  405906         2013-12-01       2014-03-19
# 1695  Insurer5610  405757         2013-11-20       2014-01-05
# 611   Insurer5268  405748         2013-11-20       2014-01-02
# 609   Insurer5268  405509         2013-11-07       2014-01-08
# 610   Insurer5268  405509         2013-11-07       2014-01-08
# 1850  Insurer5382  405438         2013-11-04       2014-01-13
# 1452  Insurer5549  405024         2013-10-08       2014-02-24
# 608   Insurer5268  404776         2013-09-24       2014-01-15
# 607   Insurer5268  404755         2013-09-23       2014-01-02
# 606   Insurer5268  404512         2013-09-09       2014-02-18
# 605   Insurer5268  404512         2013-09-09       2014-02-18
#
#                        Coverage              SubCoverage  \
# 1206  Individual Long Term Care           No SubCov - AH
# 1204                        NaN                      NaN
# 1205  Individual Long Term Care              Partnership
# 992     Group Disability Income           No SubCov - AH
# 1036     Other [Enter Coverage]                      NaN
# 990                Group Health                   Autism
# 991                         NaN                      NaN
# 1753                 Homeowners                      NaN
# 1345                        NaN                      NaN
# 1344             Auto Liability                      NaN
# 1866                 Homeowners                      NaN
# 1867                 Homeowners                      NaN
# 1069          Tenant Homeowners                      NaN
# 1068                        NaN                      NaN
# 1688                 Homeowners                      NaN
# 1451               Group Health              Out-Patient
# 1450                        NaN                      NaN
# 1865           Condo Unit Owner                      NaN
# 989                Group Health                Mammogram
# 494      Other [Enter Coverage]                      NaN
# 1543                 Homeowners                      NaN
# 1235      Worker's Compensation                      NaN
# 493              Auto Liability                      NaN
# 469              Auto Liability                      NaN
# 468                         NaN                      NaN
# 604   Individual Long Term Care     Long Term Individual
# 467        Auto Physical Damage                      NaN
# 1901                        NaN                      NaN
# 1687           Condo Unit Owner                      NaN
# 1900                 Homeowners                      NaN
# ...                         ...                      ...
# 98                         Auto                      NaN
# 97                         Auto                      NaN
# 96               Auto Liability                      NaN
# 95               Auto Liability                      NaN
# 1561                     Dental                   Dental
# 1301                 Homeowners                      NaN
# 1352             Auto Liability                      NaN
# 617                Group Health                    Other
# 1351                        NaN                      NaN
# 1696                 Homeowners                      NaN
# 1349             Auto Liability                      NaN
# 1350                        NaN                      NaN
# 1371       Auto Medical Payment                      NaN
# 616                Group Health           No SubCov - AH
# 615                         NaN                      NaN
# 614                      Dental                   Dental
# 613           Individual Health                Emergency
# 1832       Group Long Term Care           No SubCov - AH
# 612           Individual Health                    Other
# 94               Auto Liability                      NaN
# 1695                 Homeowners                      NaN
# 611                Group Health                    Other
# 609                Group Health                    Other
# 610                         NaN                      NaN
# 1850             Auto Liability                      NaN
# 1452                 Homeowners                      NaN
# 608           Individual Health  Behavl Hlth/Subst Abuse
# 607     Group Disability Income          Long Term Group
# 606                         NaN                      NaN
# 605           Individual Health       Health Care Reform
#
#                       Reason                  SubReason  \
# 1345           Closed       363018  Connecticut
# 1344           Closed       363017  Connecticut
# 1866           Closed       363000  Connecticut
# 1867           Closed       363001  Connecticut
# 1069           Closed       362987  Connecticut
# 1068           Closed       362986  Connecticut
# 1688           Closed       362975  Connecticut
# 1451           Closed       362961  Connecticut
# 1450           Closed       362960  Connecticut
# 1865           Closed       362937  Connecticut
# 989            Closed       362913  Connecticut
# 494            Closed       362896  Connecticut
# 1543           Closed       362887  Connecticut
# 1235           Closed       362877  Connecticut
# 493            Closed       362836  Connecticut
# 469            Closed       362846  Connecticut
# 468            Closed       362845  Connecticut
# 604            Closed       362830  Connecticut
# 467            Closed       362792  Connecticut
# 1901           Closed       362772  Connecticut
# 1687           Closed       362775  Connecticut
# 1900           Closed       362771  Connecticut
# ...               ...          ...          ...
# 98             Closed       345764  Connecticut
# 97             Closed       345763  Connecticut
# 96             Closed       345753  Connecticut
# 95             Closed       345731  Connecticut
# 1561           Closed       345733  Connecticut
# 1301           Closed       345704  Connecticut
# 1352           Closed       345701  Connecticut
# 617            Closed       345689  Connecticut
# 1351           Closed       345700  Connecticut
# 1696           Closed       345695  Connecticut
# 1349           Closed       345693  Connecticut
# 1350           Closed       345698  Connecticut
# 1371           Closed       345685  Connecticut
# 616            Closed       345679  Connecticut
# 615            Closed       345677  Connecticut
# 614            Closed       345667  Connecticut
# 613            Closed       345658  Connecticut
# 1832           Closed       345656  Connecticut
# 612            Closed       345652  Connecticut
# 94             Closed       345651  Connecticut
# 1695           Closed       345629  Connecticut
# 611            Closed       345626  Connecticut
# 609            Closed       345605  Connecticut
# 610            Closed       345607  Connecticut
# 1850           Closed       345599  Connecticut
# 1452           Closed       345569  Connecticut
# 608            Closed       345557  Connecticut
# 607            Closed       345556  Connecticut
# 606            Closed       345545  Connecticut
# 605            Closed       345544  Connecticut
#
# [1927 rows x 14 columns]

# %%
##droping the duplicate *InsurerID* based on the dateof registartion....
##because the previous ones will be discarded as they have no value and last followed up on will be kept***

# %%
data_train.drop_duplicates(subset ="InsurerID", 
                     keep = 'last', inplace = True)

# %%
data_train
# Out:
#          InsurerID          DRC  FileNo DateOfRegistration DateOfResolution  \
# 14652  Insurer5454  outstanding  901895         2018-04-25       2018-05-15
# 5869   Insurer5375      average  901564         2018-04-03       2018-04-05
# 15226  Insurer5778  outstanding  901174         2018-03-12       2018-03-27
# 15225  Insurer5519  outstanding  901018         2018-03-01       2018-03-25
# 15179  Insurer5900         poor  900877         2018-02-22              NaN
# 15348  Insurer5628      average  900827         2018-02-20       2018-04-03
# 15077  Insurer5479  outstanding  900849         2018-02-20       2018-03-14
# 12113  Insurer5701      average  900777         2018-02-15       2018-03-11
# 11493  Insurer5395  outstanding  900725         2018-02-14       2018-02-26
# 14538  Insurer5420  outstanding  900677         2018-02-11       2018-03-12
# 10902  Insurer5377         poor  900597         2018-02-06       2018-03-18
# 14662  Insurer5343  outstanding  900259         2018-01-17       2018-01-28
# 13800  Insurer5862      average  900243         2018-01-16       2018-01-28
# 10641  Insurer5472  outstanding  900246         2018-01-16       2018-02-19
# 5869      Other [Enter Coverage]                        NaN
# 15226          Condo Association                        NaN
# 15225                        NaN                        NaN
# 15179     Professional Liability                        NaN
# 15348            Commercial Fire                        NaN
# 15077          General Liability                        NaN
# 12113                 Homeowners                        NaN
# 11493            Commercial Auto                        NaN
# 14538           Condo Unit Owner                        NaN
# 10902     Limited Benefit Health             No SubCov - AH
# 14662            Individual Life                 Whole Life
# 13800          General Liability                        NaN
# 10641          General Liability                        NaN
# 15185            Individual Life                  Term Life
# 13065                        NaN                        NaN
# 14811            Individual Life             Universal Life
# 15114             Auto Liability                        NaN
# 15525  Individual Long Term Care             No SubCov - AH
# 14660     Other [Enter Coverage]                        NaN
# 14939          General Liability                        NaN
# 14646          General Liability                        NaN
# 15180          General Liability                        NaN
# 13788              Inland Marine                        NaN
# 15004  Individual Long Term Care  Durable Medical Equipment
# 12126     Other [Enter Coverage]             No SubCov - AH
# 6508      Commercial Multi-Peril                        NaN
# 14466          General Liability                        NaN
# 14389                 Homeowners                        NaN
# 14661          General Liability                        NaN
# ...                          ...                        ...
# 8687                  Homeowners                        NaN
# 3313                Group Health                 Anesthesia
# 9398              Auto Liability                        NaN
# 6510                Group Health    Behavl Hlth/Subst Abuse
# 9990           Individual Health               Prescription
# 7133          Short Term Medical             No SubCov - AH
# 14924    Group Disability Income           Short Term Group
# 4141       Worker's Compensation                        NaN
# 11037      Worker's Compensation                        NaN
# 14399                        NaN                        NaN
# 8440                Fire, Allied                        NaN
# 0       Exchange-Individual Hlth             No SubCov - AH
# 15443                        NaN                        NaN
# 15160                        NaN                        NaN
# 5911              Auto Liability                        NaN
# 14703             Auto Liability                        NaN
# 10887            Commercial Auto                        NaN
# 97      Exchange-Individual Hlth                      Other
# 11738     Commercial Multi-Peril                        NaN
# 5924                Group Health             No SubCov - AH
# 15373                        NaN                        NaN
# 2051                Group Health               Lab Services
# 2423           Individual Health                      Other
# 4492                Group Health  Durable Medical Equipment
# 5881             Individual Life   Viatical/Life Settlement
# 5847                     Unknown                        NaN
# 12859          Condo Association                        NaN
# 15364          Condo Association                        NaN
# 3970                  Homeowners                        NaN
# 3267                  Homeowners                        NaN
#
#                        Reason                  SubReason  \
# 14652  Unfair Claims Practice            Denial of Claim
# 5869              FOI Inquiry               No Subreason
# 15226  Unfair Claims Practice            Claim Procedure
# 15225         Marketing/Sales          Misrepresentation
# 15179  Unfair Claims Practice            Denial of Claim
# 15348  Unfair Claims Practice            Denial of Claim
# 15077  Unfair Claims Practice               Claim Delays
# 12113  Unfair Claims Practice            Denial of Claim
# 11493  Unfair Claims Practice            Denial of Claim
# 14538  Unfair Claims Practice            Claim Procedure
# 10902         Marketing/Sales            Unapproved Form
# 14662         Marketing/Sales          Misrepresentation
# 13800  Unfair Claims Practice               Claim Delays
# 10641  Unfair Claims Practice            Denial of Claim
# 15185            Underwriting          Refusal to Insure
# 13065  Unfair Claims Practice               Claim Delays
# 14811      Premium and Rating      Premium/Rate Increase
# 15114  Unfair Claims Practice               Claim Delays
# 15525  Unfair Claims Practice               Claim Delays
# 14660  Unfair Claims Practice            Denial of Claim
# ...                           ...                    ...
# 8687    Additional Money Received            Unjustified
# 3313                Claim Settled              Justified
# 9398                Claim Settled           Questionable
# 6510            Corrective Action              Justified
# 9990                Claim Settled  Furnished Information
# 7133                Claim Settled  Furnished Information
# 14924  Med Jurisdiction Explained  Furnished Information
# 4141      Company Position Upheld            Unjustified
# 11037     Company Position Upheld            Unjustified
# 14399          Contract Provision            Unjustified
# 8440    Additional Money Received           Questionable
# 0        Claim Paid With Interest              Justified
# 15443     Company Position Upheld            Unjustified
# 15160     Company Position Upheld            Unjustified
# 5911      Company Position Upheld            Unjustified
# 14703     Company Position Upheld            Unjustified
# 10887          Contract Provision            Unjustified
# 97                  Claim Settled              Justified
# 11738               Claim Settled            Unjustified
# 5924        Furnished Information  Furnished Information
# 15373          Non-Renewal Upheld            Unjustified
# 2051      Company Position Upheld    No Action Necessary
# 2423            Corrective Action  Furnished Information
# 4492    Other [Enter Disposition]  Furnished Information
# 5881        Furnished Information  Furnished Information
# 5847        Furnished Information  Furnished Information
# 12859     Company Position Upheld            Unjustified
# 15364               Claim Settled            Unjustified
# 3970     Satisfactory Explanation            Unjustified
# 3267      Company Position Upheld            Unjustified
#
#        RecoveredFromInsurer ResolutionStatus  ComplaintID        State
# 14652                  0.00           Closed       363067  Connecticut
# 5869                   0.00           Closed       362895  Connecticut
# 15226                  0.00           Closed       362663  Connecticut
# 15225                  0.00           Closed       362561  Connecticut
# 15179                  0.00        Re-Opened       362486  Connecticut
# 15348                  0.00           Closed       362455  Connecticut
# 15077                  0.00           Closed       362452  Connecticut
# 12113               9550.00           Closed       362407  Connecticut
# 11493                  0.00           Closed       362400  Connecticut
# 14538                  0.00           Closed       362357  Connecticut
# 10902                  0.00           Closed       362305  Connecticut
# 14662                  0.00           Closed       362085  Connecticut
# 13800                  0.00           Closed       362076  Connecticut
# 10641                  0.00           Closed       362077  Connecticut
# 15185                  0.00           Closed       362028  Connecticut
# 13065               2185.56           Closed       361847  Connecticut
# 14811                  0.00           Closed       361807  Connecticut
# 15114                  0.00           Closed       361695  Connecticut
# 15525                  0.00           Closed       361643  Connecticut
# 14660                  0.00           Closed       361339  Connecticut
# 14939                  0.00           Closed       361236  Connecticut
# 14646                  0.00           Closed       361059  Connecticut
# 15180                  0.00           Closed       360806  Connecticut
# 13788                  0.00           Closed       360725  Connecticut
# 15004                 87.84           Closed       360720  Connecticut
# 12126                  0.00           Closed       360498  Connecticut
# 6508                   0.00           Closed       360465  Connecticut
# 14466                  0.00           Closed       360437  Connecticut
# 14389                  0.00           Closed       360411  Connecticut
# 14661               2709.34           Closed       360314  Connecticut
# ...                     ...              ...          ...          ...
# 8687                1130.00           Closed       345575  Connecticut
# 3313              404171.32           Closed       345573  Connecticut
# 9398                5517.67           Closed       345561  Connecticut
# 6510                   0.00           Closed       345558  Connecticut
# 9990                  57.44           Closed       345555  Connecticut
# 7133                1466.08           Closed       345554  Connecticut
# 14924                  0.00           Closed       345549  Connecticut
# 4141                   0.00           Closed       345546  Connecticut
# 11037                  0.00           Closed       345547  Connecticut
# 1371    Company Position Upheld            Unjustified                  0.00
# 1832              Claim Settled  Furnished Information               3047.58
# 94      Refer-Judicial/Attorney           Questionable                  0.00
# 1695  Additional Money Received            Unjustified                  0.00
# 1850    Refer-Judicial/Attorney            Unjustified                  0.00
# 1452         Refer To Appraisal            Unjustified                  0.00
# 605    Satisfactory Explanation              Justified                  0.00
#
#      ResolutionStatus  ComplaintID        State
# 1900           Closed       362771  Connecticut
# 1868           Closed       359867  Connecticut
# 1869           Closed       359398  Connecticut
# 1898           Closed       358302  Connecticut
# 1926           Closed       357644  Connecticut
# 1848           Closed       356856  Connecticut
# 1419           Closed       356449  Connecticut
# 1897           Closed       356040  Connecticut
# 1861           Closed       355210  Connecticut
# 1896           Closed       354404  Connecticut
# 1033           Closed       353679  Connecticut
# 1346           Closed       353496  Connecticut
# 1070           Closed       352819  Connecticut
# 1895           Closed       352342  Connecticut
# 1905           Closed       351185  Connecticut
# 1891           Closed       351075  Connecticut
# 1908           Closed       350898  Connecticut
# 1902           Closed       350129  Connecticut
# 1218           Closed       349424  Connecticut
# 1843           Closed       349382  Connecticut
# 1689           Closed       349105  Connecticut
# 1919           Closed       348699  Connecticut
# 1754           Closed       348516  Connecticut
# 1286           Closed       348470  Connecticut
# 1892           Closed       348336  Connecticut
# 1870           Closed       348168  Connecticut
# 1208           Closed       347393  Connecticut
# 471            Closed       347095  Connecticut
# 1767           Closed       346879  Connecticut
# 1717           Closed       346818  Connecticut
# 1266           Closed       346787  Connecticut
# 1294           Closed       346637  Connecticut
# 1080           Closed       346609  Connecticut
# 1871           Closed       346621  Connecticut
# 1758           Closed       346542  Connecticut
# 1925           Closed       346532  Connecticut
# 1222           Closed       346435  Connecticut
# 1916           Closed       346374  Connecticut
# 1038           Closed       346356  Connecticut
# 1852           Closed       346274  Connecticut
# 1760           Closed       346264  Connecticut
# 1856           Closed       346073  Connecticut
# 1885           Closed       346024  Connecticut
# 1778           Closed       345946  Connecticut
# 496            Closed       345948  Connecticut
# 1236           Closed       345873  Connecticut
# 1544           Closed       345817  Connecticut
# 0              Closed       345815  Connecticut
# 993            Closed       345793  Connecticut
# 1567           Closed       345782  Connecticut
# 1561           Closed       345733  Connecticut
# 1301           Closed       345704  Connecticut
# 1350           Closed       345698  Connecticut
# 1371           Closed       345685  Connecticut
# 1832           Closed       345656  Connecticut
# 94             Closed       345651  Connecticut
# 1695           Closed       345629  Connecticut
# 1850           Closed       345599  Connecticut
# 1452           Closed       345569  Connecticut
# 605            Closed       345544  Connecticut

# %%
data_train.shape
# Out:
# (539, 15)

# %%
data_test.shape
# Out:
# (60, 14)

# %%
data_train.isnull().sum().sum()
# Out:
# 448

# %%
data_test.isnull().sum().sum()
# Out:
# 48

# %%
data_train.drop(['State'], axis=1, inplace=True)
data_test.drop(['State'], axis=1, inplace=True)

# %%
data_train['Coverage']=data_train['Coverage'].fillna(0)
data_test['Coverage']=data_test['Coverage'].fillna(0)

# %%
data_train['DateOfResolution']=data_train['DateOfResolution'].fillna(0)
data_test['DateOfResolution']=data_test['DateOfResolution'].fillna(0)

# %%
data_train=data_train.replace('Unknown','NaN',regex=True)
data_test=data_test.replace('Unknown','NaN',regex=True)

# %%
data_train=data_train.replace('Other','1',regex=True)
data_test=data_test.replace('Other','1',regex=True)

# %%
data_train.DRC.value_counts()
# Out:
# outstanding    276
# average        162
# poor           101
# Name: DRC, dtype: int64

# %%
data_train.DRC.value_counts()
# Out:
# outstanding    276
# average        162
# poor           101
# Name: DRC, dtype: int64

# %%
data_train.Coverage.value_counts()
# Out:
# Auto Liability               87
# Individual Life              59
# 0                            58
# Homeowners                   57
# Commercial Multi-Peril       33
# General Liability            26
# Auto                         18
# Worker's Compensation        15
# Auto Physical Damage         15
# 1 [Enter Coverage]           12
# Group Disability Income      12
# Commercial Auto              12
# Group Health                 12
# Individual Annuity           12
# Group Life                   11
# Condo Association            10
# Title Insurance               7
# Individual Long Term Care     7
# Fidelity and Surety           6
# Dental                        6
# Ind Disability Income         6
# Professional Liability        6
# Travel Insurance              5
# Individual Health             5
# Extended Warranty(1)          4
# Auto Warranty                 3
# Group/Association Trust       3
# Exchange-Individual Hlth      3
# Personal Umbrella             3
# Tenant Homeowners             2
# Limited Benefit Health        2
# NaN                           2
# Ind Medicare Supplemental     2
# Commercial Fire               2
# Inland Marine                 2
# Short Term Medical            2
# Fire, Allied                  1
# Dental/Group Assoc Trust      1
# Spec Disease-Individual       1
# Portable Electronics Ins      1
# Commercial Umbrella           1
# Vision                        1
# Credit A & H                  1
# Exchange-Group Health         1
# Dwelling Fire                 1
# Condo Unit Owner              1
# Mobile Home                   1
# A & H                         1
# Name: Coverage, dtype: int64

# %%
data_test.Coverage.value_counts()
# Out:
# 0                            9
# Homeowners                   9
# Individual Life              6
# Auto Liability               6
# Individual Long Term Care    4
# General Liability            3
# NaN                          2
# Worker's Compensation        2
# Individual Health            2
# Auto Medical Payment         2
# Commercial Auto              2
# Tenant Homeowners            1
# Short Term Medical           1
# Group Disability Income      1
# Professional Liability       1
# Auto Physical Damage         1
# Ind Disability Income        1
# Dental                       1
# Group/Association Trust      1
# A & H                        1
# Auto                         1
# Group Long Term Care         1
# Commercial Multi-Peril       1
# Watercraft                   1
# Name: Coverage, dtype: int64

# %%
data_train.SubReason.value_counts()
# Out:
# Denial of Claim              114
# Claim Delays                  92
# Claim Procedure               32
# Excessive Charges             30
# Unsatisfactory Settlement     29
# Producer Handling             23
# Unsatisfactory Offer          23
# Premium/Rate Increase         19
# Non-Renewal                   18
# Premium Refund Delay          15
# Cancellation                  14
# Misleading Advertising        11
# Comparative Negligence        10
# No Subreason                   9
# Policy Service Delay           9
# Audit                          8
# Contract Provision             8
# Misrepresentation              7
# No Coverage/Premium Paid       6
# Actual Cash Value Dispute      6
# Policy Service                 5
# Subrogation                    5
# Premium/Notice                 5
# Refusal to Insure              4
# Loss of Use                    4
# CPT Code Issue                 4
# Underwriting Delays            3
# After Mrkt Prts/Unsat Set      3
# Unfair Discrimination          3
# Carrier Never Rec'd Claim      2
# Diminished Value               2
# 1 [Enter Sub-Reason]           2
# Provider Contract Issue        2
# Underwrtng/Waivers/Rated       2
# Storage Fees                   1
# Pre-Existing Condition         1
# Mis-Quote                      1
# Unapproved Form                1
# Medical Necessity              1
# Unprofessional Conduct         1
# Underwrtng/Credit History      1
# Eligibility of Provider        1
# Replacement                    1
# Discontinuation & Replmnt      1
# Name: SubReason, dtype: int64

# %%
data_test.SubReason.value_counts()
# Out:
# Denial of Claim              9
# Claim Delays                 8
# Claim Procedure              7
# Premium/Rate Increase        4
# Unsatisfactory Settlement    4
# Audit                        2
# Non-Renewal                  2
# Cancellation                 2
# Policy Service Delay         1
# Contract Provision           1
# Carrier Never Rec'd Claim    1
# Unsatisfactory Offer         1
# Diminished Value             1
# Comparative Negligence       1
# Unapproved Form              1
# Misleading Advertising       1
# Pre-Existing Condition       1
# Premium/Notice               1
# Actual Cash Value Dispute    1
# Excessive Charges            1
# Provider Contract Issue      1
# Premium Refund Delay         1
# Refusal to Insure            1
# Unprofessional Conduct       1
# 1 [Enter Sub-Reason]         1
# Duplicate Coverage           1
# Policy Service               1
# No Coverage/Premium Paid     1
# Policy Issue Delay           1
# Discontinuation & Replmnt    1
# Name: SubReason, dtype: int64

# %%
data_train.EnforcementAction.value_counts()
# Out:
# Company Position Upheld       179
# Contract Provision             91
# Claim Settled                  58
# Corrective Action              54
# Refer-Judicial/Attorney        33
# Furnished Information          28
# Premium Refund                 10
# Complaint Withdrawn             8
# Cancellation Upheld             8
# Additional Money Received       8
# Non-Renewal Upheld              8
# Satisfactory Explanation        7
# Non-Renewal Rescinded           6
# Enter Arbitration               5
# No Cause For Action             5
# Coverage Extended               4
# Claim Paid With Interest        3
# Pol Restored/Reinstated         3
# Refer To Appraisal              3
# Cancellation Withdrawn          3
# Insufficient Information        2
# 1 [Enter Disposition]           2
# Inter-Company Arbitration       2
# Policy Not In Force             2
# External Review Info Sent       1
# Coverage Granted                1
# Record Only                     1
# Underwriting Guidelines         1
# Rate Increase Explained         1
# Provider Issue                  1
# Med Jurisdiction Explained      1
# Name: EnforcementAction, dtype: int64

# %%
data_test.EnforcementAction.value_counts()
# Out:
# Company Position Upheld      13
# Contract Provision            8
# Corrective Action             7
# Furnished Information         7
# Refer-Judicial/Attorney       4
# Claim Settled                 2
# Rate Increase Explained       2
# Premium Refund                2
# Record Only                   2
# Refer To Appraisal            2
# Non-Renewal Upheld            1
# Satisfactory Explanation      1
# Pol Restored/Reinstated       1
# Additional Money Received     1
# Cancellation Withdrawn        1
# Cancellation Upheld           1
# Claim Paid With Interest      1
# Non-Renewal Rescinded         1
# Coverage Extended             1
# Insufficient Information      1
# No Cause For Action           1
# Name: EnforcementAction, dtype: int64

# %%
data_train.Conclusion.value_counts()
# Out:
# Unjustified              376
# Justified                 65
# Furnished Information     62
# No Action Necessary       18
# Questionable              13
# Voluntary Reconsider       5
# Name: Conclusion, dtype: int64

# %%
data_test.Conclusion.value_counts()
# Out:
# Unjustified              31
# Furnished Information    11
# Justified                 8
# No Action Necessary       5
# Questionable              4
# Voluntary Reconsider      1
# Name: Conclusion, dtype: int64

# %%
##inspecting the dataset

# %%
def inspect_data(data_train):

    return pd.DataFrame({"Data Type":data_train.dtypes,"No of Levels":data_train.apply(lambda x: x.unique().shape[0],axis=0),
                         "Levels":data_train.apply(lambda x: str(x.unique()),axis=0)})
inspect_data(data_train)
# Out:
#                      Data Type  No of Levels  \
# InsurerID               object           539
# DRC                     object             3
# FileNo                   int64           524
# DateOfRegistration      object           358
# DateOfResolution        object           318
# Coverage                object            48
# SubCoverage             object            27
# Reason                  object             8
# SubReason               object            44
# EnforcementAction       object            31
# Conclusion              object             6
# RecoveredFromInsurer   float64            72
# ResolutionStatus        object             2
# ComplaintID              int64           539
#
#                                                                  Levels
# InsurerID             ['Insurer5454' 'Insurer5375' 'Insurer5778' 'In...
# DRC                                    ['outstanding' 'average' 'poor']
# FileNo                [901895 901564 901174 901018 900877 900827 900...
# DateOfRegistration    ['2018-04-25' '2018-04-03' '2018-03-12' '2018-...
# DateOfResolution      ['2018-05-15' '2018-04-05' '2018-03-27' '2018-...
# Coverage              ['Fidelity and Surety' '1 [Enter Coverage]' 'C...
# SubCoverage           [nan 'No SubCov - AH' 'Whole Life' 'Term Life'...
# Reason                ['Unfair Claims Practice' 'FOI Inquiry' 'Marke...
# SubReason             ['Denial of Claim' 'No Subreason' 'Claim Proce...
# EnforcementAction     ['Company Position Upheld' 'Furnished Informat...
# Conclusion            ['Unjustified' 'No Action Necessary' 'Justifie...
# RecoveredFromInsurer  [0.0 9550.0 2185.56 87.84 2709.34 5400.0 14000...
# ResolutionStatus                                 ['Closed' 'Re-Opened']
# ComplaintID           [363067 362895 362663 362561 362486 362455 362...

# %%
def inspect_data(data_test):

    return pd.DataFrame({"Data Type":data_test.dtypes,"No of Levels":data_test.apply(lambda x: x.unique().shape[0],axis=0),
                         "Levels":data_test.apply(lambda x: str(x.unique()),axis=0)})
inspect_data(data_test)
# Out:
#                      Data Type  No of Levels  \
# InsurerID               object            60
# FileNo                   int64            60
# DateOfRegistration      object            57
# DateOfResolution        object            54
# Coverage                object            24
# SubCoverage             object            12
# Reason                  object             4
# SubReason               object            30
# EnforcementAction       object            21
# Conclusion              object             6
# RecoveredFromInsurer   float64            10
# ResolutionStatus        object             1
# ComplaintID              int64            60
#
#                                                                  Levels
# InsurerID             ['Insurer5643' 'Insurer5303' 'Insurer5312' 'In...
# FileNo                [901365 803045 802337 800684 705600 704435 703...
# DateOfRegistration    ['2018-03-22' '2017-06-29' '2017-05-17' '2017-...
# DateOfResolution      ['2018-04-02' '2017-07-26' '2017-05-30' '2017-...
# Coverage              ['Homeowners' 'Commercial Auto' 'Individual Li...
# SubCoverage           [nan '1' 'Whole Life' 'No SubCov - AH' 'Short ...
# Reason                ['Unfair Claims Practice' 'Premium and Rating'...
# SubReason             ['Unsatisfactory Offer' 'Diminished Value' 'Un...
# EnforcementAction     ['Record Only' 'Claim Settled' 'Company Positi...
# Conclusion            ['No Action Necessary' 'Unjustified' 'Furnishe...
# RecoveredFromInsurer  [0.0 750.0 5620.4 2016.57 11952.78 1091.5 39.8...
# ResolutionStatus                                             ['Closed']
# ComplaintID           [362771 359867 359398 358302 357644 356856 356...

# %% [markdown]
# # feature engineering

# %%
from collections import Counter
get_most_common = lambda values: max(Counter(values).items(), key = lambda x: x[1])[0]

# %%
from datetime import datetime

today=datetime.now()
#today=today.strftime("%Y")
data_test['DateOfRegistration'] = pd.to_datetime(data_test['DateOfRegistration'])
#print(X_train['DOJ'].strftime("%Y"))
data_test['DateOfResolution']=round((today-data_test['DateOfRegistration'])/np.timedelta64(1,'Y'))

# %%
from datetime import datetime

today=datetime.now()
#today=today.strftime("%Y")
data_train['DateOfRegistration'] = pd.to_datetime(data_train['DateOfRegistration'])
#print(X_train['DOJ'].strftime("%Y"))
data_train['DateOfResolution']=round((today-data_train['DateOfRegistration'])/np.timedelta64(1,'Y'))

# %%
complete_reason = data_train.Reason + data_train.SubReason
complete_reason = data_test.Reason + data_test.SubReason

# %%
total_coverage=data_train.Coverage + data_train.SubCoverage
total_coverage=data_test.Coverage + data_test.SubCoverage

# %%
data_train.drop(['ResolutionStatus', 'Coverage','SubCoverage','Reason','SubReason','DateOfRegistration'],axis=1, inplace=True)
data_test.drop(['ResolutionStatus', 'Coverage','SubCoverage','Reason','SubReason','DateOfRegistration'],axis=1, inplace=True)

# %%
data_train.drop(['Conclusion', 'EnforcementAction'],axis=1, inplace=True)
data_test.drop(['Conclusion', 'EnforcementAction'],axis=1, inplace=True)

# %%
data_train.isnull().sum().sum()
# Out:
# 0

# %%
data_test.isnull().sum().sum()
# Out:
# 0

# %%
data_train.shape
# Out:
# (539, 6)

# %%
data_test.shape
# Out:
# (60, 5)

# %%
data_test.head()
# Out:
#         InsurerID  FileNo  DateOfResolution  RecoveredFromInsurer  ComplaintID
# 1900  Insurer5643  901365               2.0                   0.0       362771
# 1868  Insurer5303  803045               2.0                 750.0       359867
# 1869  Insurer5312  802337               3.0                   0.0       359398
# 1898  Insurer5470  800684               3.0                   0.0       358302
# 1926  Insurer5581  705600               3.0                   0.0       357644

# %%
data_train.head()
# Out:
#          InsurerID          DRC  FileNo  DateOfResolution  \
# 14652  Insurer5454  outstanding  901895               2.0
# 5869   Insurer5375      average  901564               2.0
# 15226  Insurer5778  outstanding  901174               2.0
# 15225  Insurer5519  outstanding  901018               2.0
# 15179  Insurer5900         poor  900877               2.0
#
#        RecoveredFromInsurer  ComplaintID
# 14652                   0.0       363067
# 5869                    0.0       362895
# 15226                   0.0       362663
# 15225                   0.0       362561
# 15179                   0.0       362486

# %%
data_train.columns
# Out:
# Index(['InsurerID', 'DRC', 'FileNo', 'DateOfResolution',
#        'RecoveredFromInsurer', 'ComplaintID'],
#       dtype='object')

# %%
##replacing the target variables of poor, average and outstanding with 1,2,3

# %%
DRC= {'poor': 1, 'average':2,'outstanding':3}
data_train.DRC =[DRC[item] for item in data_train.DRC]

# %%
data_train
# Out:
#          InsurerID  DRC  FileNo  DateOfResolution  RecoveredFromInsurer  \
# 14652  Insurer5454    3  901895               2.0                  0.00
# 5869   Insurer5375    2  901564               2.0                  0.00
# 15225       362561
# 15179       362486
# 15348       362455
# 15077       362452
# 12113       362407
# 11493       362400
# 14538       362357
# 10902       362305
# 14662       362085
# 13800       362076
# 10641       362077
# 15185       362028
# 13065       361847
# 14811       361807
# 15114       361695
# 15525       361643
# 14660       361339
# 14939       361236
# 14646       361059
# 15180       360806
# 13788       360725
# 15004       360720
# 12126       360498
# 6508        360465
# 14466       360437
# 14389       360411
# 14661       360314
# ...            ...
# 8687        345575
# 3313        345573
# 9398        345561
# 6510        345558
# 9990        345555
# 7133        345554
# 14924       345549
# 4141        345546
# 11037       345547
# 14399       345542
# 8440        345540
# 0           345537
# 15443       345527
# 15160       345525
# 5911        345522
# 14703       345523
# 10887       345519
# 97          345518
# 11738       345517
# 5924        345516
# 15373       345515
# 2051        345513
# 2423        345512
# 4492        345510
# 5881        345509
# 5847        345505
# 12859       345503
# 15364       345504
# 3970        345502
# 3267        345501
#
# [539 rows x 6 columns]

# %%
data_train.isnull().sum().sum()
# Out:
# 0

# %%
data_test.isnull().sum().sum()
# Out:
# 0

# %%
data_train.dtypes
# Out:
# InsurerID                object
# DRC                       int64
# FileNo                    int64
# DateOfResolution        float64
# RecoveredFromInsurer    float64
# ComplaintID               int64
# dtype: object

# %%
data_test.dtypes
# Out:
# InsurerID                object
# FileNo                    int64
# DateOfResolution        float64
# RecoveredFromInsurer    float64
# ComplaintID               int64
# dtype: object

# %%
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 539 entries, 14652 to 3267
# Data columns (total 6 columns):
# InsurerID               539 non-null object
# DRC                     539 non-null int64
# FileNo                  539 non-null int64
# DateOfResolution        539 non-null float64
# RecoveredFromInsurer    539 non-null float64
# ComplaintID             539 non-null int64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 29.5+ KB

# %%
##checking the shape of the datasets

# %%
data_train.shape
# Out:
# (539, 6)

# %%
data_test.shape
# Out:
# (60, 5)

# %%
##conversting insureid to float

# %%
##merging FINAL datasets***********************************************************************

# %%
##columns in train and test are different so aligning them

# %%
##PLOTS*******************************************************************

# %%
##the correlation between the variables and the target
corr = data_train.corr()
sns.heatmap(corr)
corr['DRC'].sort_values(ascending=False)
# Out:
# DRC                     1.000000
# FileNo                  0.236798
# ComplaintID             0.186366
# RecoveredFromInsurer   -0.108431
# DateOfResolution       -0.205891
# Name: DRC, dtype: float64

# %%
#Hist Plots for finding the counts of the columns in the DataSet
# %matplotlib inline
import matplotlib.pyplot as plt
data_train.hist(bins=5, figsize=(25,20))
plt.savefig("attribute_histogram_plots")
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart
labels = ['poor','average','outstanding']
sizes = [15, 30, 10]
# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0.1, 0)  
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %%
data_train.dtypes
# Out:
# InsurerID                object
# DRC                       int64
# FileNo                    int64
# DateOfResolution        float64
# RecoveredFromInsurer    float64
# ComplaintID               int64
# dtype: object

# %%
data_train
# Out:
#          InsurerID  DRC  FileNo  DateOfResolution  RecoveredFromInsurer  \
# 14652  Insurer5454    3  901895               2.0                  0.00
# 5869   Insurer5375    2  901564               2.0                  0.00
# 15226  Insurer5778    3  901174               2.0                  0.00
# 15225  Insurer5519    3  901018               2.0                  0.00
# 15179  Insurer5900    1  900877               2.0                  0.00
# 15348  Insurer5628    2  900827               2.0                  0.00
# 15077  Insurer5479    3  900849               2.0                  0.00
# 12113  Insurer5701    2  900777               2.0               9550.00
# 11493  Insurer5395    3  900725               2.0                  0.00
# 14538  Insurer5420    3  900677               2.0                  0.00
# 10902  Insurer5377    1  900597               2.0                  0.00
# 14662  Insurer5343    3  900259               2.0                  0.00
# 13800  Insurer5862    2  900243               2.0                  0.00
# 10641  Insurer5472    3  900246               2.0                  0.00
# 15185  Insurer5876    3  900165               2.0                  0.00
# 13065  Insurer5315    2  805924               2.0               2185.56
# 14811  Insurer5721    3  805856               2.0                  0.00
# 15114  Insurer5727    2  805678               2.0                  0.00
# 15525  Insurer5824    2  805625               2.0                  0.00
# 14660  Insurer5338    3  805163               2.0                  0.00
# 14939  Insurer5514    3  805006               2.0                  0.00
# 14646  Insurer5329    3  804805               2.0                  0.00
# 15180  Insurer5685    3  804453               2.0                  0.00
# 13788  Insurer5831    3  804334               2.0                  0.00
# 15004  Insurer5416    2  804306               2.0                 87.84
# 12126  Insurer5286    3  803967               2.0                  0.00
# 6508   Insurer5553    1  803896               2.0                  0.00
# 14466  Insurer5279    3  803868               2.0                  0.00
# 14389  Insurer5380    3  803845               2.0                  0.00
# 14661  Insurer5340    3  803669               2.0               2709.34
# ...            ...  ...     ...               ...                   ...
# 8687   Insurer5660    1  405141               6.0               1130.00
# 3313   Insurer5388    1  405073               6.0             404171.32
# 9398   Insurer5451    2  404905               6.0               5517.67
# 6510   Insurer5406    1  404844               6.0                  0.00
# 9990   Insurer5505    1  404757               6.0                 57.44
# 7133   Insurer5544    1  404729               6.0               1466.08
# 14924  Insurer5635    3  404560               6.0                  0.00
# 4141   Insurer5590    1  404554               6.0                  0.00
# 11037  Insurer5603    3  404554               6.0                  0.00
# 14399  Insurer5381    2  404002               6.0                  0.00
# 8440   Insurer5314    3  403969               6.0               7142.45
# 0      Insurer5266    1  403737               6.0              38220.25
# 15443  Insurer5591    2  403231               6.0                  0.00
# 15160  Insurer5709    3  403143               6.0                  0.00
# 5911   Insurer5545    2  403046               6.0                  0.00
# 14703  Insurer5786    2  403046               6.0                  0.00
# 10887  Insurer5587    2  402741               6.0                  0.00
# 97     Insurer5330    1  402569               7.0               1127.43
# 11738  Insurer5661    2  402080               7.0                  0.00
# 5924   Insurer5387    1  401969               7.0                  0.00
# 15373  Insurer5823    3  401172               7.0                  0.00
# 2051   Insurer5405    1  400530               7.0                  0.00
# 2423   Insurer5866    1  303837               7.0                  0.00
# 4492   Insurer5700    1  303753               7.0                  0.00
# 5881   Insurer5638    1  202341               9.0                  0.00
# 5847   Insurer5547    1  105636               9.0                  0.00
# 12859  Insurer5750    2  103398               9.0                  0.00
# 15364  Insurer5839    2  103398               9.0              18796.82
# 1758  Insurer5455  501041               6.0                  0.00       346542
# 1925  Insurer5712  501034               6.0                  0.00       346532
# 1222  Insurer5374  500887               6.0                  0.00       346435
# 1916  Insurer5667  500830               6.0                  0.00       346374
# 1038  Insurer5307  500778               6.0                  0.00       346356
# 1852  Insurer5269  500657               6.0                  0.00       346274
# 1760  Insurer5816  500612               6.0                  0.00       346264
# 1856  Insurer5401  500307               6.0                  0.00       346073
# 1885  Insurer5364  500238               6.0                  0.00       346024
# 1778  Insurer5850  500127               6.0                  0.00       345946
# 496   Insurer5500  500145               6.0                  0.00       345948
# 1236  Insurer5704  500039               6.0                  0.00       345873
# 1544  Insurer5552  406295               6.0                 39.80       345817
# 0     Insurer5355  406310               6.0              27325.73       345815
# 993   Insurer5289  406260               6.0                  0.00       345793
# 1567  Insurer5586  406253               6.0                  0.00       345782
# 1561  Insurer5558  406136               6.0                208.92       345733
# 1301  Insurer5488  406081               6.0                  0.00       345704
# 1350  Insurer5516  406056               6.0                  0.00       345698
# 1371  Insurer5539  406046               6.0                  0.00       345685
# 1832  Insurer5754  405963               6.0               3047.58       345656
# 94    Insurer5491  405906               6.0                  0.00       345651
# 1695  Insurer5610  405757               6.0                  0.00       345629
# 1850  Insurer5382  405438               6.0                  0.00       345599
# 1452  Insurer5549  405024               6.0                  0.00       345569
# 605   Insurer5268  404512               6.0                  0.00       345544

# %%
data_train.dtypes
# Out:
# InsurerID                object
# DRC                       int64
# FileNo                    int64
# DateOfResolution        float64
# RecoveredFromInsurer    float64
# ComplaintID               int64
# dtype: object

# %%
y = data_train['DRC']
X_test=data_test
X = data_train.drop('DRC', axis=1)

# %%
data_train.dtypes
# Out:
# InsurerID                object
# DRC                       int64
# FileNo                    int64
# DateOfResolution        float64
# RecoveredFromInsurer    float64
# ComplaintID               int64
# dtype: object

# %%
data_test.dtypes
# Out:
# InsurerID                object
# FileNo                    int64
# DateOfResolution        float64
# RecoveredFromInsurer    float64
# ComplaintID               int64
# dtype: object

# %%
num_attribute = data_train.select_dtypes(include='number').columns.tolist()
cat_attributes_train = data_train.columns.difference(num_attribute).tolist()

# %%
num_attribute = data_test.select_dtypes(include='number').columns.tolist()
cat_attributes_test = data_test.columns.difference(num_attribute).tolist()

# %%
x1_train = pd.get_dummies(X)
x1_test = pd.get_dummies(X_test)

# %%
x1_train.dtypes
# Out:
# FileNo                     int64
# DateOfResolution         float64
# RecoveredFromInsurer     float64
# ComplaintID                int64
# InsurerID_Insurer5252      uint8
# InsurerID_Insurer5253      uint8
# InsurerID_Insurer5254      uint8
# InsurerID_Insurer5255      uint8
# InsurerID_Insurer5256      uint8
# InsurerID_Insurer5257      uint8
# InsurerID_Insurer5259      uint8
# InsurerID_Insurer5260      uint8
# InsurerID_Insurer5261      uint8
# InsurerID_Insurer5262      uint8
# InsurerID_Insurer5263      uint8
# InsurerID_Insurer5264      uint8
# InsurerID_Insurer5265      uint8
# InsurerID_Insurer5266      uint8
# InsurerID_Insurer5267      uint8
# InsurerID_Insurer5270      uint8
# InsurerID_Insurer5271      uint8
# InsurerID_Insurer5272      uint8
# InsurerID_Insurer5273      uint8
# InsurerID_Insurer5275      uint8
# InsurerID_Insurer5276      uint8
# InsurerID_Insurer5278      uint8
# InsurerID_Insurer5279      uint8
# InsurerID_Insurer5280      uint8
# InsurerID_Insurer5281      uint8
# InsurerID_Insurer5282      uint8
#                           ...
# InsurerID_Insurer5878      uint8
# InsurerID_Insurer5879      uint8
# InsurerID_Insurer5880      uint8
# InsurerID_Insurer5881      uint8
# InsurerID_Insurer5882      uint8
# InsurerID_Insurer5883      uint8
# InsurerID_Insurer5884      uint8
# InsurerID_Insurer5885      uint8
# InsurerID_Insurer5886      uint8
# InsurerID_Insurer5887      uint8
# InsurerID_Insurer5888      uint8
# InsurerID_Insurer5889      uint8
# InsurerID_Insurer5890      uint8
# InsurerID_Insurer5891      uint8
# InsurerID_Insurer5892      uint8
# InsurerID_Insurer5893      uint8
# InsurerID_Insurer5894      uint8
# InsurerID_Insurer5896      uint8
# InsurerID_Insurer5897      uint8
# InsurerID_Insurer5898      uint8
# InsurerID_Insurer5899      uint8
# InsurerID_Insurer5900      uint8
# InsurerID_Insurer5901      uint8
# InsurerID_Insurer5903      uint8
# InsurerID_Insurer5904      uint8
# InsurerID_Insurer5906      uint8
# InsurerID_Insurer5907      uint8
# InsurerID_Insurer5908      uint8
# InsurerID_Insurer5909      uint8
# InsurerID_Insurer5910      uint8
# Length: 543, dtype: object

# %%
x1_test.dtypes
# Out:
# FileNo                     int64
# DateOfResolution         float64
# RecoveredFromInsurer     float64
# ComplaintID                int64
# InsurerID_Insurer5268      uint8
# InsurerID_Insurer5269      uint8
# InsurerID_Insurer5287      uint8
# InsurerID_Insurer5289      uint8
# InsurerID_Insurer5303      uint8
# InsurerID_Insurer5305      uint8
# InsurerID_Insurer5307      uint8
# InsurerID_Insurer5312      uint8
# InsurerID_Insurer5331      uint8
# InsurerID_Insurer5351      uint8
# InsurerID_Insurer5355      uint8
# InsurerID_Insurer5364      uint8
# InsurerID_Insurer5365      uint8
# InsurerID_Insurer5373      uint8
# InsurerID_Insurer5374      uint8
# InsurerID_Insurer5382      uint8
# InsurerID_Insurer5401      uint8
# InsurerID_Insurer5410      uint8
# InsurerID_Insurer5442      uint8
# InsurerID_Insurer5443      uint8
# InsurerID_Insurer5453      uint8
# InsurerID_Insurer5455      uint8
# InsurerID_Insurer5470      uint8
# InsurerID_Insurer5488      uint8
# InsurerID_Insurer5491      uint8
# InsurerID_Insurer5500      uint8
#                           ...
# InsurerID_Insurer5539      uint8
# InsurerID_Insurer5543      uint8
# InsurerID_Insurer5549      uint8
# InsurerID_Insurer5552      uint8
# InsurerID_Insurer5558      uint8
# InsurerID_Insurer5577      uint8
# InsurerID_Insurer5581      uint8
# InsurerID_Insurer5586      uint8
# InsurerID_Insurer5610      uint8
# InsurerID_Insurer5643      uint8
# InsurerID_Insurer5644      uint8
# InsurerID_Insurer5662      uint8
# InsurerID_Insurer5667      uint8
# InsurerID_Insurer5673      uint8
# InsurerID_Insurer5680      uint8
# InsurerID_Insurer5687      uint8
# InsurerID_Insurer5704      uint8
# InsurerID_Insurer5712      uint8
# InsurerID_Insurer5730      uint8
# InsurerID_Insurer5754      uint8
# InsurerID_Insurer5761      uint8
# InsurerID_Insurer5771      uint8
# InsurerID_Insurer5789      uint8
# InsurerID_Insurer5792      uint8
# InsurerID_Insurer5816      uint8
# InsurerID_Insurer5848      uint8
# InsurerID_Insurer5850      uint8
# InsurerID_Insurer5865      uint8
# InsurerID_Insurer5867      uint8
# InsurerID_Insurer5895      uint8
# Length: 64, dtype: object

# %%
X_train_aligned, X_test_aligned = x1_train.align(x1_test, join='outer', axis=1, fill_value=0)
print(X_train_aligned.shape)
print(X_test_aligned.shape)
# Out:
# (539, 603)
# (60, 603)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_train=scaler.fit_transform(X_train_aligned)
x_train.shape
# Out:
# (539, 603)

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x_test=scaler.fit_transform(X_test_aligned)
X_test_aligned.shape
# Out:
# (60, 603)

# %%
from sklearn.model_selection import train_test_split
X_train, X_validation, y_train, y_validation = train_test_split(X_train_aligned, y, test_size=0.2, random_state=0)

# %%
X.shape
# Out:
# (539, 5)

# %%
y.shape
# Out:
# (539,)

# %%
y_validation.shape
# Out:
# (108,)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(ratio='auto', random_state=1234, k_neighbors=3)
            
x_train_res, y_train_res = sm.fit_sample(X_train, y_train)

# %%
y_train_res.shape
# Out:
# (666,)

# %%
x_train_res.shape
# Out:
# (666, 603)

# %%
y_train.shape
# Out:
# (431,)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report,f1_score
def train_metrics(y_train,train_pred):
    print("Train")
   # print(accuracy_score(y_train,train_pred))
    print(f1_score(y_train,train_pred,average= "micro"))
    print(confusion_matrix(y_train,train_pred))
    print(classification_report(y_train,train_pred))

def validation_metrics(y_test,test_pred):
    print("Test")
   # print(accuracy_score(y_test,test_pred))
    print(f1_score(y_test,test_pred,average= "macro"))
    print(confusion_matrix(y_test,test_pred))
    print(classification_report(y_test,test_pred))

# %%
from sklearn.linear_model import LogisticRegression
# Model initilization
lr = LogisticRegression()
# Model training
lr.fit(X_train, y_train)
# Model predictions
lr_train_pred = lr.predict(X_train)
lr_test_pred = lr.predict(X_validation)

# %%
train_pred =   lr.predict(X_train)
test_pred=lr.predict(X_validation)

# %%
train_metrics(train_pred,y_train)
validation_metrics(y_validation,test_pred)
# Out:
# Train
# 0.5336426914153132
# [[  7   2   1]
#  [  3   3   1]
#  [ 68 126 220]]
#              precision    recall  f1-score   support
#
#           1       0.09      0.70      0.16        10
#           2       0.02      0.43      0.04         7
#           3       0.99      0.53      0.69       414
#
# avg / total       0.95      0.53      0.67       431
#
# Test
# 0.2517197452229299
# [[ 1  2 20]
#  [ 1  0 30]
#  [ 0  1 53]]
#              precision    recall  f1-score   support
#
#           1       0.50      0.04      0.08        23
#           2       0.00      0.00      0.00        31
#           3       0.51      0.98      0.68        54
#
# avg / total       0.36      0.50      0.35       108

# %%
Submission = pd.DataFrame()
Submission["InsurerID"]= data_test["InsurerID"]

# %%
test = lr.predict(X_test_aligned)
Submission["DRC"]= test
Submission.to_csv("Submit.csv")

# %%
# Model initilization
lr_res = LogisticRegression()
lr_res.fit(x_train_res, y_train_res)
# Model predictions
lr_train_res_pred = lr_res.predict(x_train_res)
lr_test_res_pred = lr_res.predict(X_validation)

print("Train_res")
print(accuracy_score(y_train_res,lr_train_res_pred))
print(confusion_matrix(y_train_res,lr_train_res_pred))
print(classification_report(y_train_res,lr_train_res_pred))

print("Test_res")
print(accuracy_score(y_validation,lr_test_res_pred))
print(confusion_matrix(y_validation,lr_test_res_pred))
print(classification_report(y_validation,lr_test_res_pred))
# Out:
# Train_res
# 0.42792792792792794
# [[191   0  31]
#  [160   1  61]
#  [129   0  93]]
#              precision    recall  f1-score   support
#
#           1       0.40      0.86      0.54       222
#           2       1.00      0.00      0.01       222
#           3       0.50      0.42      0.46       222
#
# avg / total       0.63      0.43      0.34       666
#
# Test_res
# 0.3333333333333333
# [[19  1  3]
#  [20  0 11]
#  [37  0 17]]
#              precision    recall  f1-score   support
#
#           1       0.25      0.83      0.38        23
#           2       0.00      0.00      0.00        31
#           3       0.55      0.31      0.40        54
#
# avg / total       0.33      0.33      0.28       108

# %% [markdown]
# ##Model building

# %%
##SINCE THE TARGET VARIABLE IS CATOGORICAL IT IS A LOGISTIC REGRESSION THOUGH WE REPRESENTED THE VALUE OF POOR BY 1 AND AVERAGE BY 2 AND 3 WITH OUTSTANDING DEFICIENT
##THEREFORE I USED LOGISTIC REGRESSION MODEL.

# %%
##Importing libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.utils import resample
from sklearn.preprocessing import LabelBinarizer
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.metrics import roc_curve, precision_recall_curve, auc, make_scorer, recall_score, accuracy_score, precision_score, confusion_matrix

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB(priors=None)

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_validation)

# %%
train_metrics(train_pred,y_train)
validation_metrics(test_pred ,y_validation)
# Out:
# Train
# 0.5243619489559165
# [[  4   4   1]
#  [  1   4   3]
#  [ 73 123 218]]
#              precision    recall  f1-score   support
#
#           1       0.05      0.44      0.09         9
#           2       0.03      0.50      0.06         8
#           3       0.98      0.53      0.69       414
#
# avg / total       0.94      0.52      0.66       431
#
# Test
# 0.29374797052578994
# [[ 2  0  0]
#  [ 0  1  2]
#  [21 30 52]]
#              precision    recall  f1-score   support
#
#           1       0.09      1.00      0.16         2
#           2       0.03      0.33      0.06         3
#           3       0.96      0.50      0.66       103
#
# avg / total       0.92      0.51      0.64       108

# %%
from sklearn import tree
dt = tree.DecisionTreeClassifier()   ## Instantiating DecisionTree-Classifier
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=None,
#             splitter='best')

# %%
train_pred = model.predict(X_train)
test_pred = model.predict(X_validation)

# %%
train_metrics(train_pred,y_train)
validation_metrics(test_pred ,y_validation)
# Out:
# Train
# 0.5243619489559165
# [[  4   4   1]
#  [  1   4   3]
#  [ 73 123 218]]
#              precision    recall  f1-score   support
#
#           1       0.05      0.44      0.09         9
#           2       0.03      0.50      0.06         8
#           3       0.98      0.53      0.69       414
#
# avg / total       0.94      0.52      0.66       431
#
# Test
# 0.29374797052578994
# [[ 2  0  0]
#  [ 0  1  2]
#  [21 30 52]]
#              precision    recall  f1-score   support
#
#           1       0.09      1.00      0.16         2
#           2       0.03      0.33      0.06         3
#           3       0.96      0.50      0.66       103
#
# avg / total       0.92      0.51      0.64       108

# %%
from sklearn.tree import DecisionTreeClassifier
clf_gini = DecisionTreeClassifier(criterion = "gini", random_state = 100,
                               max_depth=20, min_samples_leaf=5)
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=20,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=5, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=100,
#             splitter='best')

# %%
print('Train Accuracy =',clf_gini.score(X_train, y_train))
print('Test Accuracy =',clf_gini.score(X_validation, y_validation))
# Out:
# Train Accuracy = 0.6983758700696056
# Test Accuracy = 0.4537037037037037

# %%
import graphviz
dot_data = tree.export_graphviz(clf_gini, out_file=None, feature_names=X_train_aligned.columns, filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph.render("clf_gini")
# Out:
# 'clf_gini.pdf'

# %%
dt2_entropy = tree.DecisionTreeClassifier(criterion='entropy',max_depth =15)
dt2_entropy.fit(X_train, y_train)
print('Train Accuracy =',dt2_entropy.score(X_train, y_train))
print('Test Accuracy =',dt2_entropy.score(X_validation, y_validation))
# Out:
# Train Accuracy = 0.8677494199535963
# Test Accuracy = 0.4722222222222222

# %%
dot_data = tree.export_graphviz(dt2_entropy, out_file=None,feature_names=X_train_aligned.columns,filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph.render("dt2_entropy_maxdept15")
# Out:
# 'dt2_entropy_maxdept15.pdf'

# %%
dt3_fraction15 = tree.DecisionTreeClassifier(criterion='entropy',max_depth =15, min_weight_fraction_leaf=0.11)
dt3_fraction15.fit(X_train, y_train)
print('Train Accuracy =',dt3_fraction15.score(X_train, y_train))
print('Test Accuracy =',dt3_fraction15.score(X_validation, y_validation))
# Out:
# Train Accuracy = 0.54292343387471
# Test Accuracy = 0.5277777777777778

# %%
dot_data = tree.export_graphviz(dt3_fraction15, out_file=None,feature_names=X_train_aligned.columns,filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph.render("dt3_fraction15")
# Out:
# 'dt3_fraction15.pdf'

# %%
dt4_maxleaf9 = tree.DecisionTreeClassifier(criterion='entropy',max_leaf_nodes=9)
dt4_maxleaf9.fit(X_train, y_train)
print('Train Accuracy =',dt4_maxleaf9.score(X_train, y_train))
print('Test Accuracy =',dt4_maxleaf9.score(X_validation, y_validation))
# Out:
# Train Accuracy = 0.580046403712297
# Test Accuracy = 0.5370370370370371

# %%
dot_data = tree.export_graphviz(dt4_maxleaf9, out_file=None,feature_names=X_train_aligned.columns,filled=True, rounded=True)
graph = graphviz.Source(dot_data)
graph.render("dt4_maxleaf9")
# Out:
# 'dt4_maxleaf9.pdf'

# %%
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
import pydotplus

dot_data = StringIO()
export_graphviz(dt4_maxleaf9, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,feature_names=X_test_aligned.columns,class_names=['1','2','3'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue()) 
graph.write_png('y_train.png')
Image(graph.create_png())

# %%
Df=data_train.loc[data_train["RecoveredFromInsurer"] > 5000,:]

# %%
Df.tail(20)
# Out:
#          InsurerID  DRC  FileNo  DateOfResolution  RecoveredFromInsurer  \
# 7297   Insurer5259    2  700431               4.0               5935.46
# 15228  Insurer5899    2  604474               4.0              18174.38
# 14976  Insurer5770    2  601428               5.0              58467.02
# 15399  Insurer5847    2  504919               5.0               9750.00
# 13419  Insurer5342    3  503746               5.0              12839.46
# 14833  Insurer5383    2  503731               5.0              60000.00
# 4180   Insurer5592    1  502973               5.0              28832.00
# 9341   Insurer5429    3  501935               6.0               7006.24
# 14961  Insurer5521    3  501752               6.0              14000.00
# 12198  Insurer5725    1  501434               6.0              23274.39
# 8377   Insurer5300    2  500958               6.0              31102.80
# 3917   Insurer5541    1  500056               6.0              25052.88
# 13438  Insurer5826    1  406070               6.0              10536.88
# 8083   Insurer5285    3  405734               6.0              37630.20
# 13704  Insurer5845    3  405391               6.0              15834.27
# 3313   Insurer5388    1  405073               6.0             404171.32
# 9398   Insurer5451    2  404905               6.0               5517.67
# 8440   Insurer5314    3  403969               6.0               7142.45
# 0      Insurer5266    1  403737               6.0              38220.25
# 15364  Insurer5839    2  103398               9.0              18796.82
#
#        ComplaintID
# 7297        354160
# 15228       352859
# 14976       350829
# 15399       349225
# 13419       348414
# 14833       348412
# 4180        347886
# 9341        347163
# 14961       347023
# 12198       346819
# 8377        346476
# 3917        345887
# 13438       345697
# 8083        345627
# 13704       345592
# 3313        345573
# 9398        345561
# 8440        345540
# 0           345537
# 15364       345504

# %%
data_test['RecoveredFromInsurer'].plot(kind='bar',figsize=(15,6))

#loc,labels=plt.yticks()
#plt.yticks(loc,loc/1e9,fontsize=24)##set loc and label
plt.ylabel('RecoveredFromInsurer',fontsize=14)
plt.xlabel('InsurerID',fontsize=16)
plt.xticks(fontsize=12)
plt.title('Details of Fraud Insurers',fontsize=20)
plt.show()

# %%
data_train["RecoveredFromInsurer"].describe()

ax = sns.boxplot(y = data_train["RecoveredFromInsurer"],whis=[1,99.00])

# %% [markdown]
# PLOTTING THE LEARNING CURVE TO FIND OUT THE VARIANCE IN THE TRAIN DATA AND TEST DATA

# %%
#!pip install mlxtend  
from mlxtend.plotting import plot_learning_curves
import matplotlib.pyplot as plt
#from mlxtend.data import iris_data
from mlxtend.preprocessing import shuffle_arrays_unison
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# %%
plot_learning_curves(X_train, y_train, X_validation,y_validation,clf=lr)
plt.show()

# %%
plot_learning_curves(X_train, y_train, X_validation,y_validation,clf=model)
plt.show()

# %%
plot_learning_curves(X_train, y_train, X_validation,y_validation,clf=dt4_maxleaf9)
plt.show()

# %%
import matplotlib.pyplot as plt

# Pie chart
labels = ['poor','average','outstanding']
sizes = [15, 30, 10]
# only "explode" the 2nd slice (i.e. 'Hogs')
explode = (0, 0.1, 0)  
fig1, ax1 = plt.subplots()
ax1.pie(sizes, explode=explode, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
# Equal aspect ratio ensures that pie is drawn as a circle
ax1.axis('equal')  
plt.tight_layout()
plt.show()
